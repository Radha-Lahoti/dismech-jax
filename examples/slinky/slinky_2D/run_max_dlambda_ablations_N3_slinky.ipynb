# %%
import json
import os
from helpers import *
from properties import *
from run_max_dlambda_ablation_minimal import (
    MaxDlambdaAblationConfig,
    run_max_dlambda_ablation,
    summarize_best_stable_step,
    subset_all,
    subset_main_paper_candidates,
)
jax.config.update("jax_enable_x64", True)

# %%
train_file = "../experiment_data/n3_slinky_train_dataset.npz"
valid_file = "../experiment_data/n3_slinky_test_dataset.npz"


cfg = MaxDlambdaAblationConfig(
        
        der_K_diag=(0.02, 0.02),
        der_K_chol=(0.02, 0.0, 0.02),
        hidden=(10,),
        corr_factor=0.01,
        input_mode="raw",
        zero_reference=True,
        activation="tanh",

        # Keep these identical to your run_architectures.py test
        n_epochs=500,
        lr=5e-2,
        seed_list=(42,),
        valid_every=1,

        max_dlambda_values=(1e-2, 5e-2, 1e-1, 5e-1, 1.0),
        iters=15,
        ls_steps=10,
        abs_tol=1e-4,
        rel_tol=1e-4,
        train_fail_on_nonconvergence=True,
        prediction_fail_on_nonconvergence=False,

        output_dir="max_dlambda_ablation_outputs_n3_slinky_run1",
        save_npz=True,
        verbose=True,

        stop_after_first_failure=False,

        strict_finite_check=True,

        save_summary_json=True,
    )


# Example: choose only selected architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     # "chol_stiffness_mlp",
#     # add whatever you want here
# ]

selected_architectures = subset_all()

selected_architectures = [
    arch for arch in selected_architectures
    if arch not in ["chol_stiffness_signed_mlp", "diag_stiffness_icnn", "chol_stiffness_icnn", "chol_stiffness_signed_icnn"]
]

# or:
# selected_architectures = subset_main_paper_candidates()

results = run_max_dlambda_ablation(
    # properties=StripN9Properties(),
    properties=SlinkyN3Properties(),
    # properties=SlinkyN5Properties(),
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)

summary = summarize_best_stable_step(results)
print("\nLargest stable max_dlambda by architecture:")
print(json.dumps(summary, indent=2))
# Out:
# ====================================================================================================
# Architecture : diag_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.299e-02
# Epoch 100 | Train: 6.285e-04 | Valid: 2.432e-04
# Epoch 200 | Train: 3.853e-04 | Valid: 2.769e-04
# Epoch 300 | Train: 3.506e-04 | Valid: 3.008e-04
# Epoch 400 | Train: 3.407e-04 | Valid: 3.066e-04
# [diag_energy_baseline] seed=42 | max_dlambda=1.000e-02 | train=3.370e-04 | valid=3.079e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.299e-02
# Epoch 100 | Train: 6.285e-04 | Valid: 2.432e-04
# Epoch 200 | Train: 3.853e-04 | Valid: 2.769e-04
# Epoch 300 | Train: 3.506e-04 | Valid: 3.008e-04
# Epoch 400 | Train: 3.407e-04 | Valid: 3.066e-04
# [diag_energy_baseline] seed=42 | max_dlambda=5.000e-02 | train=3.370e-04 | valid=3.079e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.299e-02
# Epoch 100 | Train: 6.285e-04 | Valid: 2.432e-04
# Epoch 200 | Train: 3.853e-04 | Valid: 2.769e-04
# Epoch 300 | Train: 3.506e-04 | Valid: 3.008e-04
# Epoch 400 | Train: 3.407e-04 | Valid: 3.066e-04
# [diag_energy_baseline] seed=42 | max_dlambda=1.000e-01 | train=3.370e-04 | valid=3.079e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.299e-02
# Epoch 100 | Train: 6.285e-04 | Valid: 2.432e-04
# Epoch 200 | Train: 3.853e-04 | Valid: 2.769e-04
# Epoch 300 | Train: 3.506e-04 | Valid: 3.008e-04
# Epoch 400 | Train: 3.407e-04 | Valid: 3.066e-04
# [diag_energy_baseline] seed=42 | max_dlambda=5.000e-01 | train=3.370e-04 | valid=3.079e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.299e-02
# Epoch 100 | Train: 6.285e-04 | Valid: 2.432e-04
# Epoch 200 | Train: 3.853e-04 | Valid: 2.769e-04
# Epoch 300 | Train: 3.506e-04 | Valid: 3.008e-04
# Epoch 400 | Train: 3.407e-04 | Valid: 3.066e-04
# [diag_energy_baseline] seed=42 | max_dlambda=1.000e+00 | train=3.370e-04 | valid=3.079e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.294e-02
# Epoch 100 | Train: 1.299e-04 | Valid: 2.369e-04
# Epoch 200 | Train: 3.701e-05 | Valid: 2.777e-04
# [FAILED] diag_energy_mlp: training_convergence_failure
# [diag_energy_mlp] seed=42 | max_dlambda=1.000e-02 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : diag_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.294e-02
# Epoch 100 | Train: 1.299e-04 | Valid: 2.369e-04
# [FAILED] diag_energy_mlp: training_convergence_failure
# [diag_energy_mlp] seed=42 | max_dlambda=5.000e-02 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : diag_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.294e-02
# Epoch 100 | Train: 1.299e-04 | Valid: 2.369e-04
# [FAILED] diag_energy_mlp: training_convergence_failure
# [diag_energy_mlp] seed=42 | max_dlambda=1.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : diag_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.294e-02
# Epoch 100 | Train: 1.299e-04 | Valid: 2.369e-04
# [FAILED] diag_energy_mlp: training_convergence_failure
# [diag_energy_mlp] seed=42 | max_dlambda=5.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : diag_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 3.294e-02
# Epoch 100 | Train: 1.299e-04 | Valid: 2.369e-04
# [FAILED] diag_energy_mlp: training_convergence_failure
# [diag_energy_mlp] seed=42 | max_dlambda=1.000e+00 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : diag_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 2.933e-02
# Epoch 100 | Train: 5.664e-04 | Valid: 1.237e-03
# Epoch 200 | Train: 2.329e-04 | Valid: 3.971e-04
# Epoch 300 | Train: 1.524e-04 | Valid: 2.135e-04
# Epoch 400 | Train: 1.309e-04 | Valid: 1.744e-04
# [diag_energy_icnn] seed=42 | max_dlambda=1.000e-02 | train=1.228e-04 | valid=1.601e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 2.933e-02
# Epoch 100 | Train: 5.664e-04 | Valid: 1.237e-03
# Epoch 200 | Train: 2.329e-04 | Valid: 3.971e-04
# Epoch 300 | Train: 1.524e-04 | Valid: 2.135e-04
# Epoch 400 | Train: 1.309e-04 | Valid: 1.744e-04
# [diag_energy_icnn] seed=42 | max_dlambda=5.000e-02 | train=1.228e-04 | valid=1.601e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 2.933e-02
# Epoch 100 | Train: 5.664e-04 | Valid: 1.237e-03
# Epoch 200 | Train: 2.329e-04 | Valid: 3.971e-04
# Epoch 300 | Train: 1.524e-04 | Valid: 2.135e-04
# Epoch 400 | Train: 1.309e-04 | Valid: 1.744e-04
# [diag_energy_icnn] seed=42 | max_dlambda=1.000e-01 | train=1.228e-04 | valid=1.601e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 2.933e-02
# Epoch 100 | Train: 5.664e-04 | Valid: 1.237e-03
# Epoch 200 | Train: 2.329e-04 | Valid: 3.971e-04
# Epoch 300 | Train: 1.524e-04 | Valid: 2.135e-04
# Epoch 400 | Train: 1.309e-04 | Valid: 1.744e-04
# [diag_energy_icnn] seed=42 | max_dlambda=5.000e-01 | train=1.228e-04 | valid=1.601e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 2.933e-02
# Epoch 100 | Train: 5.664e-04 | Valid: 1.237e-03
# Epoch 200 | Train: 2.329e-04 | Valid: 3.971e-04
# Epoch 300 | Train: 1.524e-04 | Valid: 2.135e-04
# Epoch 400 | Train: 1.309e-04 | Valid: 1.744e-04
# [diag_energy_icnn] seed=42 | max_dlambda=1.000e+00 | train=1.228e-04 | valid=1.601e-04 | SUCCESS
# ====================================================================================================
# Architecture : mlp_energy
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] mlp_energy: training_convergence_failure
# [mlp_energy] seed=42 | max_dlambda=1.000e-02 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : mlp_energy
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] mlp_energy: training_convergence_failure
# [mlp_energy] seed=42 | max_dlambda=5.000e-02 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : mlp_energy
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] mlp_energy: training_convergence_failure
# [mlp_energy] seed=42 | max_dlambda=1.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : mlp_energy
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] mlp_energy: training_convergence_failure
# [mlp_energy] seed=42 | max_dlambda=5.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : mlp_energy
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] mlp_energy: training_convergence_failure
# [mlp_energy] seed=42 | max_dlambda=1.000e+00 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : icnn_energy
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] icnn_energy: training_convergence_failure
# [icnn_energy] seed=42 | max_dlambda=1.000e-02 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : icnn_energy
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] icnn_energy: training_convergence_failure
# [icnn_energy] seed=42 | max_dlambda=5.000e-02 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : icnn_energy
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] icnn_energy: training_convergence_failure
# [icnn_energy] seed=42 | max_dlambda=1.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : icnn_energy
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] icnn_energy: training_convergence_failure
# [icnn_energy] seed=42 | max_dlambda=5.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : icnn_energy
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# [FAILED] icnn_energy: training_convergence_failure
# [icnn_energy] seed=42 | max_dlambda=1.000e+00 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : chol_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.433e-02
# Epoch 100 | Train: 5.704e-04 | Valid: 1.019e-03
# Epoch 200 | Train: 3.915e-04 | Valid: 3.911e-04
# Epoch 300 | Train: 3.555e-04 | Valid: 2.878e-04
# Epoch 400 | Train: 3.433e-04 | Valid: 2.592e-04
# [chol_energy_baseline] seed=42 | max_dlambda=1.000e-02 | train=3.385e-04 | valid=2.493e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.433e-02
# Epoch 100 | Train: 5.704e-04 | Valid: 1.019e-03
# Epoch 200 | Train: 3.915e-04 | Valid: 3.911e-04
# Epoch 300 | Train: 3.555e-04 | Valid: 2.878e-04
# Epoch 400 | Train: 3.433e-04 | Valid: 2.592e-04
# [chol_energy_baseline] seed=42 | max_dlambda=5.000e-02 | train=3.385e-04 | valid=2.493e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.433e-02
# Epoch 100 | Train: 5.704e-04 | Valid: 1.019e-03
# Epoch 200 | Train: 3.915e-04 | Valid: 3.911e-04
# Epoch 300 | Train: 3.555e-04 | Valid: 2.878e-04
# Epoch 400 | Train: 3.433e-04 | Valid: 2.592e-04
# [chol_energy_baseline] seed=42 | max_dlambda=1.000e-01 | train=3.385e-04 | valid=2.493e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.433e-02
# Epoch 100 | Train: 5.704e-04 | Valid: 1.019e-03
# Epoch 200 | Train: 3.915e-04 | Valid: 3.911e-04
# Epoch 300 | Train: 3.555e-04 | Valid: 2.878e-04
# Epoch 400 | Train: 3.433e-04 | Valid: 2.592e-04
# [chol_energy_baseline] seed=42 | max_dlambda=5.000e-01 | train=3.385e-04 | valid=2.493e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_baseline
# which_case   : baseline
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.433e-02
# Epoch 100 | Train: 5.704e-04 | Valid: 1.019e-03
# Epoch 200 | Train: 3.915e-04 | Valid: 3.911e-04
# Epoch 300 | Train: 3.555e-04 | Valid: 2.878e-04
# Epoch 400 | Train: 3.433e-04 | Valid: 2.592e-04
# [chol_energy_baseline] seed=42 | max_dlambda=1.000e+00 | train=3.385e-04 | valid=2.493e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.431e-02
# Epoch 100 | Train: 1.378e-04 | Valid: 1.154e-03
# Epoch 200 | Train: 6.431e-05 | Valid: 6.339e-04
# Epoch 300 | Train: 5.165e-05 | Valid: 5.157e-04
# Epoch 400 | Train: 4.849e-05 | Valid: 4.796e-04
# [chol_energy_mlp] seed=42 | max_dlambda=1.000e-02 | train=4.745e-05 | valid=4.664e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.431e-02
# Epoch 100 | Train: 1.378e-04 | Valid: 1.154e-03
# Epoch 200 | Train: 6.431e-05 | Valid: 6.339e-04
# Epoch 300 | Train: 5.165e-05 | Valid: 5.157e-04
# Epoch 400 | Train: 4.849e-05 | Valid: 4.796e-04
# [chol_energy_mlp] seed=42 | max_dlambda=5.000e-02 | train=4.745e-05 | valid=4.664e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.431e-02
# [FAILED] chol_energy_mlp: training_convergence_failure
# [chol_energy_mlp] seed=42 | max_dlambda=1.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : chol_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.431e-02
# [FAILED] chol_energy_mlp: training_convergence_failure
# [chol_energy_mlp] seed=42 | max_dlambda=5.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : chol_energy_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.852e-02 | Valid: 1.431e-02
# [FAILED] chol_energy_mlp: training_convergence_failure
# [chol_energy_mlp] seed=42 | max_dlambda=1.000e+00 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : chol_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 1.284e-02
# Epoch 100 | Train: 2.637e-04 | Valid: 6.710e-04
# Epoch 200 | Train: 7.429e-05 | Valid: 2.238e-04
# Epoch 300 | Train: 5.562e-05 | Valid: 2.049e-04
# Epoch 400 | Train: 5.370e-05 | Valid: 2.111e-04
# [chol_energy_icnn] seed=42 | max_dlambda=1.000e-02 | train=5.312e-05 | valid=2.142e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 1.284e-02
# Epoch 100 | Train: 2.637e-04 | Valid: 6.710e-04
# Epoch 200 | Train: 7.429e-05 | Valid: 2.238e-04
# Epoch 300 | Train: 5.562e-05 | Valid: 2.049e-04
# Epoch 400 | Train: 5.370e-05 | Valid: 2.111e-04
# [chol_energy_icnn] seed=42 | max_dlambda=5.000e-02 | train=5.312e-05 | valid=2.142e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 1.284e-02
# Epoch 100 | Train: 2.637e-04 | Valid: 6.710e-04
# Epoch 200 | Train: 7.429e-05 | Valid: 2.238e-04
# Epoch 300 | Train: 5.562e-05 | Valid: 2.049e-04
# Epoch 400 | Train: 5.370e-05 | Valid: 2.111e-04
# [chol_energy_icnn] seed=42 | max_dlambda=1.000e-01 | train=5.312e-05 | valid=2.142e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 1.284e-02
# Epoch 100 | Train: 2.637e-04 | Valid: 6.710e-04
# Epoch 200 | Train: 7.429e-05 | Valid: 2.238e-04
# Epoch 300 | Train: 5.562e-05 | Valid: 2.049e-04
# Epoch 400 | Train: 5.370e-05 | Valid: 2.111e-04
# [chol_energy_icnn] seed=42 | max_dlambda=5.000e-01 | train=5.312e-05 | valid=2.142e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_energy_icnn
# which_case   : ICNN
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 6.846e-02 | Valid: 1.284e-02
# Epoch 100 | Train: 2.637e-04 | Valid: 6.710e-04
# Epoch 200 | Train: 7.429e-05 | Valid: 2.238e-04
# Epoch 300 | Train: 5.562e-05 | Valid: 2.049e-04
# Epoch 400 | Train: 5.370e-05 | Valid: 2.111e-04
# [chol_energy_icnn] seed=42 | max_dlambda=1.000e+00 | train=5.312e-05 | valid=2.142e-04 | SUCCESS
# ====================================================================================================
# Architecture : diag_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 2.108e-03 | Valid: 2.556e-03
# Epoch 100 | Train: 4.749e-04 | Valid: 1.470e-03
# Epoch 200 | Train: 2.723e-04 | Valid: 9.455e-04
# [FAILED] diag_stiffness_mlp: training_convergence_failure
# [diag_stiffness_mlp] seed=42 | max_dlambda=1.000e-02 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : diag_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 2.108e-03 | Valid: 2.556e-03
# Epoch 100 | Train: 4.749e-04 | Valid: 1.470e-03
# [FAILED] diag_stiffness_mlp: training_convergence_failure
# [diag_stiffness_mlp] seed=42 | max_dlambda=5.000e-02 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : diag_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 2.108e-03 | Valid: 2.556e-03
# Epoch 100 | Train: 4.749e-04 | Valid: 1.470e-03
# Epoch 200 | Train: 2.723e-04 | Valid: 9.456e-04
# [FAILED] diag_stiffness_mlp: training_convergence_failure
# [diag_stiffness_mlp] seed=42 | max_dlambda=1.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : diag_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 2.108e-03 | Valid: 2.556e-03
# Epoch 100 | Train: 4.749e-04 | Valid: 1.470e-03
# Epoch 200 | Train: 2.723e-04 | Valid: 9.456e-04
# [FAILED] diag_stiffness_mlp: training_convergence_failure
# [diag_stiffness_mlp] seed=42 | max_dlambda=5.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : diag_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 2.108e-03 | Valid: 2.556e-03
# Epoch 100 | Train: 4.749e-04 | Valid: 1.470e-03
# Epoch 200 | Train: 2.723e-04 | Valid: 9.456e-04
# [FAILED] diag_stiffness_mlp: training_convergence_failure
# [diag_stiffness_mlp] seed=42 | max_dlambda=1.000e+00 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : chol_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 1.757e-03 | Valid: 2.140e-03
# Epoch 100 | Train: 2.887e-04 | Valid: 9.740e-04
# Epoch 200 | Train: 1.727e-04 | Valid: 7.096e-04
# Epoch 300 | Train: 1.233e-04 | Valid: 5.694e-04
# Epoch 400 | Train: 1.022e-04 | Valid: 5.076e-04
# [chol_stiffness_mlp] seed=42 | max_dlambda=1.000e-02 | train=9.567e-05 | valid=4.837e-04 | SUCCESS
# ====================================================================================================
# Architecture : chol_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-02
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 1.757e-03 | Valid: 2.140e-03
# Epoch 100 | Train: 1.994e-04 | Valid: 7.972e-04
# Epoch 200 | Train: 9.531e-05 | Valid: 4.784e-04
# [FAILED] chol_stiffness_mlp: training_convergence_failure
# [chol_stiffness_mlp] seed=42 | max_dlambda=5.000e-02 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : chol_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 1.757e-03 | Valid: 2.140e-03
# [FAILED] chol_stiffness_mlp: training_convergence_failure
# [chol_stiffness_mlp] seed=42 | max_dlambda=1.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : chol_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 5.000e-01
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 1.757e-03 | Valid: 2.140e-03
# [FAILED] chol_stiffness_mlp: training_convergence_failure
# [chol_stiffness_mlp] seed=42 | max_dlambda=5.000e-01 | train=nan | valid=nan | FAIL (training_convergence_failure)
# ====================================================================================================
# Architecture : chol_stiffness_mlp
# which_case   : MLP
# seed         : 42
# max_dlambda  : 1.000e+00
# iters        : 15
# ls_steps     : 10
# abs_tol      : 1.000e-04
# rel_tol      : 1.000e-04
# training fail_on_nonconvergence      : True
# validation loss fail_on_nonconvergence: False
# prediction fail_on_nonconvergence    : False
# ====================================================================================================
# Epoch 000 | Train: 1.757e-03 | Valid: 2.140e-03
# [FAILED] chol_stiffness_mlp: training_convergence_failure
# [chol_stiffness_mlp] seed=42 | max_dlambda=1.000e+00 | train=nan | valid=nan | FAIL (training_convergence_failure)
#
# Largest stable max_dlambda by architecture:
# {
#   "diag_energy_baseline": {
#     "42": {
#       "largest_stable_max_dlambda": 1.0,
#       "best_valid_loss_among_stable": 0.00030792417728751605
#     }
#   },
#   "diag_energy_mlp": {
#     "42": {
#       "largest_stable_max_dlambda": null,
#       "best_valid_loss_among_stable": null
#     }
#   },
#   "diag_energy_icnn": {
#     "42": {
#       "largest_stable_max_dlambda": 1.0,
#       "best_valid_loss_among_stable": 0.00016009108993326435
#     }
#   },
#   "mlp_energy": {
#     "42": {
#       "largest_stable_max_dlambda": null,
#       "best_valid_loss_among_stable": null
#     }
#   },
#   "icnn_energy": {
#     "42": {
#       "largest_stable_max_dlambda": null,
#       "best_valid_loss_among_stable": null
#     }
#   },
#   "chol_energy_baseline": {
#     "42": {
#       "largest_stable_max_dlambda": 1.0,
#       "best_valid_loss_among_stable": 0.0002493299477987198
#     }
#   },
#   "chol_energy_mlp": {
#     "42": {
#       "largest_stable_max_dlambda": 0.05,
#       "best_valid_loss_among_stable": 0.0004663767694321282
#     }
#   },
#   "chol_energy_icnn": {
#     "42": {
#       "largest_stable_max_dlambda": 1.0,
#       "best_valid_loss_among_stable": 0.0002142450069409175
#     }
#   },
#   "diag_stiffness_mlp": {
#     "42": {
#       "largest_stable_max_dlambda": null,
#       "best_valid_loss_among_stable": null
#     }
#   },
#   "chol_stiffness_mlp": {
#     "42": {
#       "largest_stable_max_dlambda": 0.01,
#       "best_valid_loss_among_stable": 0.0004837305083093533
#     }
#   }
# }

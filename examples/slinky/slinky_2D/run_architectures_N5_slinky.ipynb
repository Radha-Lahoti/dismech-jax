# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from properties import *

# %%
train_file = "../experiment_data/n5_slinky_train_dataset_merged1and2.npz"
valid_file = "../experiment_data/n5_slinky_test_dataset.npz"

# %%
from run_architectures import *
dir = "arch_sweep_outputs_n5_slinky_traj2_merged1and2"

cfg = SweepConfig(
    der_K_diag=(0.02, 0.002),
    der_K_chol=(0.02, 0.0, 0.002),
    hidden=(10,),
    corr_factor=0.01,
    input_mode="raw",
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=1e-2,
    seed=42,
    output_dir=dir,
    iters = 10,
    max_dlambda = 5e-2,
    train_fail_on_nonconvergence=True,
    prediction_fail_on_nonconvergence=False,
    hessian_reg_strength=1e-7,
    hessian_reg_probes=1,
    hessian_reg_seed=0,
    abs_tol=1e-4,
    rel_tol=1e-4,

)


# # Example: choose only selected architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     # "chol_stiffness_mlp",
#     # add whatever you want here
# ]
# selected_architectures = subset_all()  # run all architectures

# remove mlp_energy, chol_stiffness_signed_mlp, all stiffness_icnn from the plot since they are so bad that they throw off the scale and make it hard to see differences between the other architectures
# selected_architectures = [
#     arch for arch in subset_all()
#     if arch not in ["mlp_energy", "chol_stiffness_signed_mlp", "diag_stiffness_icnn", "chol_stiffness_icnn", "chol_stiffness_signed_icnn"]
# ]

# good architectures
selected_architectures = [
    "diag_energy_baseline",
    "chol_energy_baseline",
    "diag_energy_icnn",
    "chol_energy_icnn",
    "diag_stiffness_mlp",
    "chol_stiffness_mlp",
    "diag_energy_mlp",
    "chol_energy_mlp",
    # add whatever you want here
]

# %%
results = run_architecture_sweep(
    properties=SlinkyN5Properties(),
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)
# Out:
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   hessian_reg_strength    : 1e-07
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   exp_dir                 : arch_sweep_outputs_n5_slinky_traj2_merged1and2/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-07__hprobe_1__hseed_0
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# [FAILED] diag_energy_baseline: convergence_failure
# ==========================================================================================
# Running architecture: chol_energy_baseline
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   hessian_reg_strength    : 1e-07
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   exp_dir                 : arch_sweep_outputs_n5_slinky_traj2_merged1and2/chol_energy_baseline__hid_10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-07__hprobe_1__hseed_0
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# [FAILED] chol_energy_baseline: convergence_failure
# ==========================================================================================
# Running architecture: diag_energy_icnn
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   hessian_reg_strength    : 1e-07
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   exp_dir                 : arch_sweep_outputs_n5_slinky_traj2_merged1and2/diag_energy_icnn__hid_10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-07__hprobe_1__hseed_0
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# [FAILED] diag_energy_icnn: convergence_failure
# ==========================================================================================
# Running architecture: chol_energy_icnn
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   hessian_reg_strength    : 1e-07
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   exp_dir                 : arch_sweep_outputs_n5_slinky_traj2_merged1and2/chol_energy_icnn__hid_10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-07__hprobe_1__hseed_0
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results = run_architecture_sweep(
#       2     properties=SlinkyN5Properties(),
#       3     train_file=train_file,
#       4     valid_file=valid_file,
#       5     cfg=cfg,
#       6     selected_architectures=selected_architectures,
#       7 )
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/run_architectures.py:744, in run_architecture_sweep(properties, train_file, valid_file, cfg, selected_architectures)
#     742 spec = registry[arch_name]
#     743 try:
# --> 744     results[arch_name] = run_one_architecture(
#     745         properties=properties,
#     746         train_file=train_file,
#     747         valid_file=valid_file,
#     748         spec=spec,
#     749         cfg=cfg,
#     750     )
#     751 except Exception as e:
#     752     # extra guard, though run_one_architecture already catches failures
#     753     failure_reason = _classify_exception_message(repr(e))
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/run_architectures.py:512, in run_one_architecture(properties, train_file, valid_file, spec, cfg)
#     501     (
#     502         baseline_callback,
#     503         baseline_history_epochs,
#     504         baseline_history_values,
#     505         baseline_history_labels,
#     506     ) = _make_baseline_history_callback(spec.model_cls)
#     508 try:
#     509     # -------------------------
#     510     # Train
#     511     # -------------------------
# --> 512     model, train_hist, valid_hist = train_model(
#     513         properties=properties,
#     514         model_cls=spec.model_cls,
#     515         params=params,
#     516         train_file=train_file,
#     517         valid_file=valid_file,
#     518         n_epochs=cfg.n_epochs,
#     519         lr=cfg.lr,
#     520         snapshot_fn=snapshot_fn,
#     521         snapshot_every=cfg.energy_snapshot_every,
#     522         snapshot_epochs=snapshot_epochs,
#     523         snapshot_before_training=snapshot_before_training,
#     524         epoch_callback=baseline_callback,
#     525         valid_every=cfg.valid_every,
#     526         max_dlambda=cfg.max_dlambda,
#     527         iters=cfg.iters,
#     528         ls_steps=cfg.ls_steps,
#     529         abs_tol=cfg.abs_tol,
#     530         rel_tol=cfg.rel_tol,
#     531         fail_on_nonconvergence=_train_fail_on_nonconvergence(cfg),
#     532         hessian_reg_strength=cfg.hessian_reg_strength,
#     533         hessian_reg_probes=cfg.hessian_reg_probes,
#     534         hessian_reg_seed=cfg.hessian_reg_seed,
#     535     )
#     537     # -------------------------
#     538     # Predict
#     539     # -------------------------
#     540     base, aux = get_slinky(properties)
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/util.py:378, in train_model(properties, model_cls, params, train_file, valid_file, n_epochs, lr, snapshot_fn, snapshot_every, snapshot_epochs, snapshot_before_training, epoch_callback, valid_every, max_dlambda, iters, ls_steps, abs_tol, rel_tol, fail_on_nonconvergence, hessian_reg_strength, hessian_reg_probes, hessian_reg_seed)
#     375 snapshot_epoch_set = None if snapshot_epochs is None else set(snapshot_epochs)
#     377 if snapshot_fn is not None and snapshot_before_training:
# --> 378     snapshot_fn(
#     379         model=model,
#     380         epoch=-1,
#     381         base=base,
#     382         aux=aux,
#     383         train=train,
#     384         valid=valid,
#     385         train_loss=jnp.nan,
#     386         val_loss=jnp.nan,
#     387     )
#     389 if epoch_callback is not None:
#     390     epoch_callback(
#     391         model=model,
#     392         epoch=-1,
#     393         train_loss=jnp.nan,
#     394         val_loss=jnp.nan,
#     395     )
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/util_energy_plots.py:406, in make_energy_snapshot_fn.<locals>.snapshot_fn(model, epoch, base, aux, train, valid, train_loss, val_loss)
#     403     spec_local.n_grid = n_grid_snapshot
#     405 # Single solve only for the chosen trajectory
# --> 406 qs, auxs, del_strains = solve_with_strain_history(
#     407     model=model,
#     408     base=base,
#     409     aux=aux,
#     410     idx_b=idx_b_plot,
#     411     xb=xb_plot,
#     412     lambdas=lambdas_plot,
#     413     max_dlambda=max_dlambda,
#     414     iters=iters,
#     415     ls_steps=ls_steps,
#     416 )
#     418 _ = auxs  # retained for debugging if you later want to save/use it
#     420 tag = "initial" if epoch == -1 else None
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/util_energy_plots.py:70, in solve_with_strain_history(model, base, aux, idx_b, xb, lambdas, max_dlambda, iters, ls_steps)
#      67     raise ValueError(f"Expected xb.ndim in {{2, 3}}, got shape {xb.shape}")
#      69 rod = base.with_bc(bc)
# ---> 70 qs, auxs = rod.solve_with_aux(
#      71     model,
#      72     lambdas,
#      73     aux,
#      74     max_dlambda=max_dlambda,
#      75     iters=iters,
#      76     ls_steps=ls_steps,
#      77 )
#      78 del_strains = rod.get_del_strain_history(qs, auxs)
#      79 return qs, auxs, del_strains
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/equinox/_module/_prebuilt.py:82, in Partial.__call__(self, *args, **kwargs)
#      69 def __call__(self, *args: Any, **kwargs: Any) -> _Return:
#      70     """Call the wrapped `self.func`.
#      71
#      72     **Arguments:**
#    (...)     80     The result of the wrapped function.
#      81     """
# ---> 82     return self.func(*self.args, *args, **kwargs, **self.keywords)
#
#     [... skipping hidden 3 frame]
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:259, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     255   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     256                      "`jit`, but 'no_tracing' is set")
#     257 p, args_flat = _trace_for_jit(fun, jit_info, args, kwargs)
#     258 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 259  executable, pgle_profiler, const_args) = _run_python_pjit(
#     260      p, args_flat, fun, jit_info, args, kwargs)
#     262 maybe_fastpath_data = _get_fastpath_data(
#     263     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     264     pgle_profiler, const_args)
#     266 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:142, in _run_python_pjit(p, args_flat, fun, jit_info, args, kwargs)
#     140   args_flat = map(core.full_lower, args_flat)
#     141   core.check_eval_args(args_flat)
# --> 142   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     143       *args_flat, **p.params)
#     144 else:
#     145   out_flat = jit_p.bind(*args_flat, **p.params)
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:1202, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1191 arg_types = map(convert_to_metaty, args)
#    1192 computation = _resolve_and_lower(
#    1193     arg_types, jaxpr=jaxpr, in_shardings=in_shardings,
#    1194     out_shardings=out_shardings, in_layouts=in_layouts,
#    (...)   1200     compiler_options_kvs=compiler_options_kvs,
#    1201 )
# -> 1202 compiled = computation.compile()
#    1204 # This check is expensive so only do it if enable_checks is on.
#    1205 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py:2510, in MeshComputation.compile(self, compiler_options, device_assignment)
#    2507 assert isinstance(compilation_device_list, (type(None), xc.DeviceList))
#    2509 if self._executable is None or compiler_options_kvs or device_assignment:
# -> 2510   executable = UnloadedMeshExecutable.from_hlo(
#    2511       self._name, self._hlo, **self.compile_args,
#    2512       compiler_options_kvs=compiler_options_kvs,
#    2513       device_list=compilation_device_list)
#    2514   if not compiler_options_kvs:
#    2515     self._executable = executable
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py:3056, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    3053       break
#    3055 util.test_event("pxla_cached_compilation")
# -> 3056 xla_executable = _cached_compilation(
#    3057     hlo, name, mesh, spmd_lowering,
#    3058     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    3059     allow_prop_to_outputs, tuple(host_callbacks), backend, device_list,
#    3060     pmap_nreps, compiler_options_kvs, pgle_profiler)
#    3062 if auto_spmd_lowering:
#    3063   assert mesh is not None
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py:2837, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2829 compile_options = create_compile_options(
#    2830     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2831     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2832     dev, pmap_nreps, compiler_options)
#    2834 with dispatch.log_elapsed_time(
#    2835     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2836     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2837   xla_executable = compiler.compile_or_get_cached(
#    2838       backend, computation, dev, compile_options, host_callbacks,
#    2839       da, pgle_profiler)
#    2840 return xla_executable
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/compiler.py:478, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, executable_devices, pgle_profiler)
#     476 else:
#     477   log_persistent_cache_miss(module_name, cache_key)
# --> 478   return _compile_and_write_cache(
#     479       backend,
#     480       computation,
#     481       executable_devices,
#     482       compile_options,
#     483       host_callbacks,
#     484       module_name,
#     485       cache_key,
#     486   )
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/compiler.py:746, in _compile_and_write_cache(backend, computation, executable_devices, compile_options, host_callbacks, module_name, cache_key)
#     736 def _compile_and_write_cache(
#     737     backend: xc.Client,
#     738     computation: ir.Module,
#    (...)    743     cache_key: str,
#     744 ) -> xc.LoadedExecutable:
#     745   start_time = time.monotonic()
# --> 746   executable = backend_compile_and_load(
#     747       backend, computation, executable_devices, compile_options, host_callbacks
#     748   )
#     749   compile_time = time.monotonic() - start_time
#     750   _cache_write(
#     751       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     752   )
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/profiler.py:359, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     356 @wraps(func)
#     357 def wrapper(*args, **kwargs):
#     358   with TraceAnnotation(name, **decorator_kwargs):
# --> 359     return func(*args, **kwargs)
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/jax/_src/compiler.py:362, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     353       return backend.compile_and_load(
#     354           module,
#     355           executable_devices=executable_devices,
#     356           compile_options=options,
#     357           host_callbacks=host_callbacks,
#     358       )
#     359     # Some backends don't have `host_callbacks` option yet
#     360     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     361     # to take in `host_callbacks`
# --> 362     return backend.compile_and_load(
#     363         module,
#     364         executable_devices=executable_devices,
#     365         compile_options=options,
#     366     )
#     367 except _jax.JaxRuntimeError as e:
#     368   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %%
from architecture_plots import plot_architecture_comparison_paper

plot_architecture_comparison_paper(
    architectures=selected_architectures,
    # architectures=subset_all(),
    results_dir=dir,
    traj_idx=0,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from architecture_plots import plot_architecture_comparison_paper
# ----> 3 plot_architecture_comparison_paper(
#       4     architectures=selected_architectures,
#       5     # architectures=subset_all(),
#       6     results_dir=dir,
#       7     traj_idx=0,
#       8 )
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:760, in plot_architecture_comparison_paper(architectures, results_dir, output_dir, traj_idx, x_idx, z_idx)
#     758 results_by_arch = {}
#     759 for arch in architectures:
# --> 760     results_path = _find_architecture_results_path(results_dir, arch)
#     761     results_by_arch[arch] = _load_results_file(results_path)
#     763 if traj_idx is not None:
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:347, in _find_architecture_results_path(results_dir, arch_name)
#     344         matches.append(results_path)
#     346 if len(matches) == 0:
# --> 347     raise FileNotFoundError(
#     348         f"No saved results found for architecture '{arch_name}' in '{results_dir}'."
#     349     )
#     350 if len(matches) > 1:
#     351     raise ValueError(
#     352         f"Multiple saved results found for architecture '{arch_name}' in '{results_dir}': "
#     353         f"{matches}. Please keep one run per architecture in that directory."
#     354     )
#
# FileNotFoundError: No saved results found for architecture 'diag_energy_baseline' in 'arch_sweep_outputs_n5_slinky_traj2_merged1and2'.

# %%
# from architecture_plots import plot_architecture_comparison_paper
# plot_dir = "arch_sweep_outputs_run4_n5_slinky"
# # good architectures
# plot_architectures = [
#     "diag_energy_baseline",
#     "chol_energy_baseline",
#     "diag_energy_icnn",
#     "chol_energy_icnn",
#     "diag_stiffness_mlp",
#     "chol_stiffness_mlp",
#     "diag_energy_mlp",
#     "chol_energy_mlp",
#     # add whatever you want here
# ]

# plot_architecture_comparison_paper(
#     architectures=plot_architectures,
#     # architectures=subset_all(),
#     results_dir=plot_dir,
#     traj_idx=2,
# )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 16
#       3 # good architectures
#       4 plot_architectures = [
#       5     "diag_energy_baseline",
#       6     "chol_energy_baseline",
#    (...)     13     # add whatever you want here
#      14 ]
# ---> 16 plot_architecture_comparison_paper(
#      17     architectures=plot_architectures,
#      18     # architectures=subset_all(),
#      19     results_dir=plot_dir,
#      20     traj_idx=2,
#      21 )
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:760, in plot_architecture_comparison_paper(architectures, results_dir, output_dir, traj_idx, x_idx, z_idx)
#     758 results_by_arch = {}
#     759 for arch in architectures:
# --> 760     results_path = _find_architecture_results_path(results_dir, arch)
#     761     results_by_arch[arch] = _load_results_file(results_path)
#     763 if traj_idx is not None:
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:347, in _find_architecture_results_path(results_dir, arch_name)
#     344         matches.append(results_path)
#     346 if len(matches) == 0:
# --> 347     raise FileNotFoundError(
#     348         f"No saved results found for architecture '{arch_name}' in '{results_dir}'."
#     349     )
#     350 if len(matches) > 1:
#     351     raise ValueError(
#     352         f"Multiple saved results found for architecture '{arch_name}' in '{results_dir}': "
#     353         f"{matches}. Please keep one run per architecture in that directory."
#     354     )
#
# FileNotFoundError: No saved results found for architecture 'diag_energy_baseline' in 'arch_sweep_outputs_run4_n5_slinky'.

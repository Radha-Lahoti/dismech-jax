# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from properties import *

# %%
train_file = "../experiment_data/n5_slinky_train_dataset.npz"
valid_file = "../experiment_data/n5_slinky_test_dataset.npz"

# %%
from run_architectures import *
dir = "arch_sweep_outputs_run2_n5_slinky"

cfg = SweepConfig(
    der_K_diag=(0.02, 0.02),
    der_K_chol=(0.02, 0.0, 0.02),
    hidden=(10,),
    corr_factor=0.1,
    input_mode="raw",
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=1e-2,
    seed=42,
    output_dir=dir,
    iters = 10,
    max_dlambda = 5e-2
)


# # Example: choose only selected architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     # "chol_stiffness_mlp",
#     # add whatever you want here
# ]
# selected_architectures = subset_all()  # run all architectures

# remove mlp_energy, chol_stiffness_signed_mlp, all stiffness_icnn from the plot since they are so bad that they throw off the scale and make it hard to see differences between the other architectures
selected_architectures = [
    arch for arch in subset_all()
    if arch not in ["mlp_energy", "chol_stiffness_signed_mlp", "diag_stiffness_icnn", "chol_stiffness_icnn", "chol_stiffness_signed_icnn"]
]

# %%
results = run_architecture_sweep(
    properties=SlinkyN5Properties(),
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)
# Out:
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n5_slinky/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 3.070e-03 | Valid: 3.457e-03
# Epoch 100 | Train: 9.263e-04 | Valid: 8.463e-04
# Epoch 200 | Train: 8.272e-04 | Valid: 6.315e-04
# Epoch 300 | Train: 8.249e-04 | Valid: 6.244e-04
# Epoch 400 | Train: 8.248e-04 | Valid: 6.234e-04
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:193: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
from architecture_plots import plot_architecture_comparison_paper

plot_architecture_comparison_paper(
    architectures=selected_architectures,
    # architectures=subset_all(),
    results_dir=dir,
    traj_idx=0,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 from architecture_plots import plot_architecture_comparison_paper
# ----> 3 plot_architecture_comparison_paper(
#       4     architectures=selected_architectures,
#       5     # architectures=subset_all(),
#       6     results_dir=dir,
#       7     traj_idx=0,
#       8 )
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:497, in plot_architecture_comparison_paper(architectures, results_dir, output_dir, traj_idx, x_idx, z_idx)
#     495 results_by_arch = {}
#     496 for arch in architectures:
# --> 497     results_path = _find_architecture_results_path(results_dir, arch)
#     498     results_by_arch[arch] = _load_results_file(results_path)
#     500 colors = _architecture_colors(architectures)
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:310, in _find_architecture_results_path(results_dir, arch_name)
#     306     raise FileNotFoundError(
#     307         f"No saved results found for architecture '{arch_name}' in '{results_dir}'."
#     308     )
#     309 if len(matches) > 1:
# --> 310     raise ValueError(
#     311         f"Multiple saved results found for architecture '{arch_name}' in '{results_dir}': "
#     312         f"{matches}. Please keep one run per architecture in that directory."
#     313     )
#     314 return matches[0]
#
# ValueError: Multiple saved results found for architecture 'diag_energy_baseline' in 'arch_sweep_outputs_all12_n5_slinky': ['arch_sweep_outputs_all12_n5_slinky/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_42__mdl_0.05__it_10/results.npz', 'arch_sweep_outputs_all12_n5_slinky/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/results.npz']. Please keep one run per architecture in that directory.

# %%
# from architecture_plots import plot_saved_results

# results_path = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/results.npz"
# plot_output_dir = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/replotted"


# plot_saved_results(
#     results_path=results_path,
#     output_dir=plot_output_dir, # if output_dir = None, image will just be shown and not saved
#     show=True,
#     make_component_plots=True,
# )

# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from properties import *

# %%
train_file = "../experiment_data/n5_slinky_train_dataset.npz"
valid_file = "../experiment_data/n5_slinky_test_dataset.npz"

# %%
from run_architectures import *
dir = "arch_sweep_outputs_run4_n5_slinky"

cfg = SweepConfig(
    der_K_diag=(0.02, 0.01),
    der_K_chol=(0.02, 0.0, 0.01),
    hidden=(10,10),
    corr_factor=0.01,
    input_mode="raw",
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=1e-2,
    seed=42,
    output_dir=dir,
    iters = 10,
    max_dlambda = 5e-2
)


# # Example: choose only selected architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     # "chol_stiffness_mlp",
#     # add whatever you want here
# ]
# selected_architectures = subset_all()  # run all architectures

# remove mlp_energy, chol_stiffness_signed_mlp, all stiffness_icnn from the plot since they are so bad that they throw off the scale and make it hard to see differences between the other architectures
# selected_architectures = [
#     arch for arch in subset_all()
#     if arch not in ["mlp_energy", "chol_stiffness_signed_mlp", "diag_stiffness_icnn", "chol_stiffness_icnn", "chol_stiffness_signed_icnn"]
# ]

# good architectures
selected_architectures = [
    # "diag_energy_baseline",
    # "chol_energy_baseline",
    # "diag_energy_icnn",
    # "chol_energy_icnn",
    "diag_stiffness_mlp",
    "chol_stiffness_mlp",
    "diag_energy_mlp",
    "chol_energy_mlp",
    # add whatever you want here
]

# %%
results = run_architecture_sweep(
    properties=SlinkyN5Properties(),
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)
# Out:
# ==========================================================================================
# Running architecture: diag_stiffness_mlp
#   model_cls               : DiagonalPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run4_n5_slinky/diag_stiffness_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 6.011e-03 | Valid: 6.738e-03
# Epoch 100 | Train: 6.186e-03 | Valid: 6.984e-03
# Epoch 200 | Train: 6.016e-03 | Valid: 6.747e-03
# Epoch 300 | Train: 5.986e-03 | Valid: 6.616e-03
# Epoch 400 | Train: 5.971e-03 | Valid: 6.551e-03
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:234: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# ==========================================================================================
# Running architecture: chol_stiffness_mlp
#   model_cls               : CholeskyPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run4_n5_slinky/chol_stiffness_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 5.964e-03 | Valid: 6.700e-03
# Epoch 100 | Train: 4.208e-03 | Valid: 7.399e-03
# Epoch 200 | Train: 3.486e-03 | Valid: 7.521e-03
# Epoch 300 | Train: 3.206e-03 | Valid: 6.975e-03
# Epoch 400 | Train: 3.117e-03 | Valid: 7.072e-03
# ==========================================================================================
# Running architecture: diag_energy_mlp
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run4_n5_slinky/diag_energy_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.620e-03 | Valid: 2.742e-03
# Epoch 100 | Train: 6.047e-04 | Valid: 4.386e-04
# Epoch 200 | Train: 3.485e-04 | Valid: 4.935e-04
# Epoch 300 | Train: 2.936e-04 | Valid: 4.841e-04
# Epoch 400 | Train: 2.760e-04 | Valid: 5.200e-04
# ==========================================================================================
# Running architecture: chol_energy_mlp
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run4_n5_slinky/chol_energy_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.620e-03 | Valid: 2.813e-03
# Epoch 100 | Train: 6.723e-04 | Valid: 7.094e-04
# Epoch 200 | Train: 3.308e-04 | Valid: 5.307e-04
# Epoch 300 | Train: 2.763e-04 | Valid: 2.259e-03
# Epoch 400 | Train: 2.550e-04 | Valid: 1.843e-03

# %%
from architecture_plots import plot_architecture_comparison_paper

plot_architecture_comparison_paper(
    architectures=selected_architectures,
    # architectures=subset_all(),
    results_dir=dir,
    traj_idx=0,
)
# Out:
# {'training_loss': 'arch_sweep_outputs_run4_n5_slinky/paper_ready_architecture_comparison/training_loss_comparison.pdf',
#  'validation_loss': 'arch_sweep_outputs_run4_n5_slinky/paper_ready_architecture_comparison/validation_loss_comparison.pdf',
#  'training_trajectory': 'arch_sweep_outputs_run4_n5_slinky/paper_ready_architecture_comparison/training_trajectory_comparison.pdf',
#  'validation_trajectory': 'arch_sweep_outputs_run4_n5_slinky/paper_ready_architecture_comparison/validation_trajectory_comparison.pdf',
#  'training_xz_trajectory': 'arch_sweep_outputs_run4_n5_slinky/paper_ready_architecture_comparison/training_xz_trajectory_comparison.pdf',
#  'validation_xz_trajectory': 'arch_sweep_outputs_run4_n5_slinky/paper_ready_architecture_comparison/validation_xz_trajectory_comparison.pdf',
#  'combined_xz_trajectory': 'arch_sweep_outputs_run4_n5_slinky/paper_ready_architecture_comparison/combined_xz_trajectory_comparison.pdf',
#  'colors': {'diag_stiffness_mlp': (np.float64(0.12156862745098039),
#    np.float64(0.4666666666666667),
#    np.float64(0.7058823529411765),
#    np.float64(1.0)),
#   'chol_stiffness_mlp': (np.float64(1.0),
#    np.float64(0.4980392156862745),
#    np.float64(0.054901960784313725),
#    np.float64(1.0)),
#   'diag_energy_mlp': (np.float64(0.17254901960784313),
#    np.float64(0.6274509803921569),
#    np.float64(0.17254901960784313),
#    np.float64(1.0)),
#   'chol_energy_mlp': (np.float64(0.8392156862745098),
#    np.float64(0.15294117647058825),
#    np.float64(0.1568627450980392),
#    np.float64(1.0))}}

# %%
from architecture_plots import plot_architecture_comparison_paper
plot_dir = "arch_sweep_outputs_run4_n5_slinky"
# good architectures
plot_architectures = [
    "diag_energy_baseline",
    "chol_energy_baseline",
    "diag_energy_icnn",
    "chol_energy_icnn",
    "diag_stiffness_mlp",
    "chol_stiffness_mlp",
    "diag_energy_mlp",
    "chol_energy_mlp",
    # add whatever you want here
]

plot_architecture_comparison_paper(
    architectures=plot_architectures,
    # architectures=subset_all(),
    results_dir=plot_dir,
    traj_idx=2,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 16
#       3 # good architectures
#       4 plot_architectures = [
#       5     "diag_energy_baseline",
#       6     "chol_energy_baseline",
#    (...)     13     # add whatever you want here
#      14 ]
# ---> 16 plot_architecture_comparison_paper(
#      17     architectures=plot_architectures,
#      18     # architectures=subset_all(),
#      19     results_dir=plot_dir,
#      20     traj_idx=2,
#      21 )
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:760, in plot_architecture_comparison_paper(architectures, results_dir, output_dir, traj_idx, x_idx, z_idx)
#     758 results_by_arch = {}
#     759 for arch in architectures:
# --> 760     results_path = _find_architecture_results_path(results_dir, arch)
#     761     results_by_arch[arch] = _load_results_file(results_path)
#     763 if traj_idx is not None:
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:347, in _find_architecture_results_path(results_dir, arch_name)
#     344         matches.append(results_path)
#     346 if len(matches) == 0:
# --> 347     raise FileNotFoundError(
#     348         f"No saved results found for architecture '{arch_name}' in '{results_dir}'."
#     349     )
#     350 if len(matches) > 1:
#     351     raise ValueError(
#     352         f"Multiple saved results found for architecture '{arch_name}' in '{results_dir}': "
#     353         f"{matches}. Please keep one run per architecture in that directory."
#     354     )
#
# FileNotFoundError: No saved results found for architecture 'diag_energy_baseline' in 'arch_sweep_outputs_run4_n5_slinky'.

# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from properties import *

# %%
train_file = "../experiment_data/n9_strip_train_dataset.npz"
valid_file = "../experiment_data/n9_strip_test_dataset.npz"

# %%
from run_architectures import *

cfg = SweepConfig(
    der_K_diag=(20, 0.002),
    der_K_chol=(20, 0.0, 0.002),
    hidden=(10,),
    corr_factor=1.0,
    input_mode="raw",
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=1e-2,
    seed=0,
    output_dir="arch_sweep_outputs_all12_n9strip_testing",
)


# Example: choose only selected architectures
selected_architectures = [
    "diag_energy_baseline",
    # "chol_stiffness_mlp",
    # add whatever you want here
]
# selected_architectures = subset_all()  # run all architectures

# %%
results = run_architecture_sweep(
    properties=StripN9Properties(),
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)
# Out:
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 1.0
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.310e-03 | Valid: 6.417e-04
# Epoch 100 | Train: 1.188e-03 | Valid: 5.596e-04
# Epoch 200 | Train: 1.188e-03 | Valid: 5.600e-04
# Epoch 300 | Train: 1.188e-03 | Valid: 5.600e-04
# Epoch 400 | Train: 1.188e-03 | Valid: 5.599e-04
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:193: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
from architecture_plots import plot_architecture_comparison_paper

plot_architecture_comparison_paper(
    architectures=selected_architectures,
    # architectures=subset_all(),
    results_dir="arch_sweep_outputs_all12_n9strip_testing",
    traj_idx=0,
)
# Out:
# {'training_loss': 'arch_sweep_outputs_all12_n9strip_testing/paper_ready_architecture_comparison/training_loss_comparison.pdf',
#  'validation_loss': 'arch_sweep_outputs_all12_n9strip_testing/paper_ready_architecture_comparison/validation_loss_comparison.pdf',
#  'training_trajectory': 'arch_sweep_outputs_all12_n9strip_testing/paper_ready_architecture_comparison/training_trajectory_comparison.pdf',
#  'validation_trajectory': 'arch_sweep_outputs_all12_n9strip_testing/paper_ready_architecture_comparison/validation_trajectory_comparison.pdf',
#  'colors': {'diag_energy_baseline': array([0.12156863, 0.46666667, 0.70588235, 1.        ])}}

# %%
# from architecture_plots import plot_saved_results

# results_path = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/results.npz"
# plot_output_dir = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/replotted"


# plot_saved_results(
#     results_path=results_path,
#     output_dir=plot_output_dir, # if output_dir = None, image will just be shown and not saved
#     show=True,
#     make_component_plots=True,
# )

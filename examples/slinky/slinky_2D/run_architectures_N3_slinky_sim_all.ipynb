# %% [markdown]
# # N3 Slinky Sim Architecture Sweep
#
# Runs all architecture variants on the 3-node simulated slinky data using the same core model/training settings as `2d_slinky_train_from_sim_LLT.ipynb`. All outputs are collected under one `OUTPUT_DIR`, with per-architecture plots, energy landscapes, paper-ready comparison plots, and post-training Hessian diagnostics.

# %%
import os
from pathlib import Path

import jax
import jax.numpy as jnp

jax.config.update("jax_enable_x64", True)
os.environ.setdefault("XLA_PYTHON_CLIENT_PREALLOCATE", "false")

from properties import SlinkyN3Properties
from run_architectures import SweepConfig, run_architecture_sweep

# ---------------------------------------------------------
# Dataset/properties/model/training settings copied from
# 2d_slinky_train_from_sim_LLT.ipynb.
# ---------------------------------------------------------
ROOT = Path.cwd()
OUTPUT_DIR = ROOT / "arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True"
PAPER_PLOT_DIR = OUTPUT_DIR / "paper_ready_architecture_comparison"

train_file = "../simulation_data_2D/3_noded/n3_slinky_sim_train_dataset_7_trajs.npz"
valid_file = "../simulation_data_2D/3_noded/n3_slinky_sim_test_dataset_6_trajs.npz"

properties = SlinkyN3Properties()
K_init_chol = (0.02, 0.0, 0.05)
K_init_diag = (0.02, 0.05)

cfg = SweepConfig(
    der_K_diag=K_init_diag,
    der_K_chol=K_init_chol,
    hidden=(10, 10),
    corr_factor=0.05,
    input_mode="invariant",
    only_stretching_NN=True,
    only_bending_NN=False,
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=1e-3,
    seed=42,
    valid_every=1,
    max_dlambda=1e-2,
    iters=20,
    ls_steps=10,
    abs_tol=1e-4,
    rel_tol=1e-4,
    early_stop=True,
    train_fail_on_nonconvergence=True,
    prediction_fail_on_nonconvergence=False,
    hessian_reg_strength=1e-4,
    hessian_reg_probes=1,
    hessian_reg_seed=0,
    force_key="F",
    force_loss_strength=0.1,
    force_components=(0,),
    force_sign=1.0,
    return_loss_components=True,
    early_stopping=True,
    early_stopping_patience=200,
    early_stopping_min_delta=1e-5,
    early_stopping_warmup_epochs=200,
    restore_best_model=True,
    output_dir=str(OUTPUT_DIR),
    save_npz=True,
    save_model=True,
    save_plots=True,
    save_force_predictions=True,
    plot_force_predictions=True,
    save_hessian_diagnostics=False,  # post-process in the Hessian cell below
    save_energy_landscapes=True,
    energy_snapshot_initial=True,
    energy_snapshot_final=True,
    energy_snapshot_epochs=(),
    energy_snapshot_every=None,
    energy_snapshot_use_valid=True,
    energy_snapshot_dpi=180,
    energy_snapshot_n_grid=None,
    verbose=True,
    continue_on_failure=True,
)

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"Saving all results under: {OUTPUT_DIR.resolve()}")
# Out:
# Saving all results under: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True

# %%
from run_architectures import subset_all

# All registered architecture variants.
selected_architectures = subset_all()

# For a quicker debug pass, temporarily uncomment a smaller list:
# selected_architectures = [
#     "diag_energy_baseline",
#     "diag_energy_mlp",
#     "chol_energy_baseline",
# ]

selected_architectures = [
    arch for arch in selected_architectures
    if arch not in ["chol_stiffness_signed_mlp", "chol_stiffness_signed_icnn"]
]

print(f"Running {len(selected_architectures)} architectures:")
for name in selected_architectures:
    print(f"  - {name}")

print("\nPer-architecture plots:", cfg.save_plots)
print("Energy landscape snapshots:", cfg.save_energy_landscapes)
print("Force prediction plots:", cfg.plot_force_predictions)
# Out:
# Running 12 architectures:
#   - diag_energy_baseline
#   - diag_energy_mlp
#   - diag_energy_icnn
#   - mlp_energy
#   - icnn_energy
#   - chol_energy_baseline
#   - chol_energy_mlp
#   - chol_energy_icnn
#   - diag_stiffness_mlp
#   - diag_stiffness_icnn
#   - chol_stiffness_mlp
#   - chol_stiffness_icnn
#
# Per-architecture plots: True
# Energy landscape snapshots: True
# Force prediction plots: True

# %%
results = run_architecture_sweep(
    properties=properties,
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)

successes = [name for name, result in results.items() if result["success"]]
failures = {name: result["failure_reason"] for name, result in results.items() if not result["success"]}

print(f"Succeeded: {len(successes)}/{len(results)}")
if failures:
    print("Failures:")
    for name, reason in failures.items():
        print(f"  - {name}: {reason}")
else:
    print("No architecture failures.")
# Out:
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_energy_baseline__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 1.313e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.052e-01 | Valid disp: 2.705e-02 | Valid force: 7.819e-01
# Epoch 100 | Train total: 1.187e-01 | Train disp: 2.704e-02 | Train force: 8.754e-01 | Valid total: 9.409e-02 | Valid disp: 2.248e-02 | Valid force: 7.161e-01
# Epoch 200 | Train total: 1.088e-01 | Train disp: 2.335e-02 | Train force: 8.112e-01 | Valid total: 8.544e-02 | Valid disp: 1.940e-02 | Valid force: 6.604e-01
# Epoch 300 | Train total: 1.028e-01 | Train disp: 2.122e-02 | Train force: 7.675e-01 | Valid total: 7.984e-02 | Valid disp: 1.761e-02 | Valid force: 6.224e-01
# Epoch 400 | Train total: 9.919e-02 | Train disp: 2.020e-02 | Train force: 7.443e-01 | Valid total: 7.696e-02 | Valid disp: 1.674e-02 | Valid force: 6.022e-01
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:234: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# ==========================================================================================
# Running architecture: diag_energy_mlp
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_energy_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 1.313e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.052e-01 | Valid disp: 2.705e-02 | Valid force: 7.819e-01
# Epoch 100 | Train total: 1.137e-01 | Train disp: 2.503e-02 | Train force: 8.443e-01 | Valid total: 8.902e-02 | Valid disp: 2.070e-02 | Valid force: 6.831e-01
# Epoch 200 | Train total: 9.734e-02 | Train disp: 1.970e-02 | Train force: 7.302e-01 | Valid total: 7.411e-02 | Valid disp: 1.649e-02 | Valid force: 5.762e-01
# Epoch 300 | Train total: 8.988e-02 | Train disp: 1.765e-02 | Train force: 6.703e-01 | Valid total: 6.689e-02 | Valid disp: 1.492e-02 | Valid force: 5.197e-01
# Epoch 400 | Train total: 8.611e-02 | Train disp: 1.680e-02 | Train force: 6.434e-01 | Valid total: 6.360e-02 | Valid disp: 1.426e-02 | Valid force: 4.935e-01
# ==========================================================================================
# Running architecture: diag_energy_icnn
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_energy_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 1.038e-01 | Train disp: 2.322e-02 | Train force: 7.646e-01 | Valid total: 6.841e-02 | Valid disp: 1.581e-02 | Valid force: 5.260e-01
# Epoch 100 | Train total: 3.309e-02 | Train disp: 9.302e-03 | Train force: 1.535e-01 | Valid total: 1.343e-02 | Valid disp: 8.553e-03 | Valid force: 4.872e-02
# Epoch 200 | Train total: 3.190e-02 | Train disp: 9.644e-03 | Train force: 1.415e-01 | Valid total: 1.346e-02 | Valid disp: 8.949e-03 | Valid force: 4.511e-02
# Epoch 300 | Train total: 3.190e-02 | Train disp: 9.649e-03 | Train force: 1.390e-01 | Valid total: 1.349e-02 | Valid disp: 8.959e-03 | Valid force: 4.528e-02
# Epoch 400 | Train total: 3.117e-02 | Train disp: 9.631e-03 | Train force: 1.379e-01 | Valid total: 1.340e-02 | Valid disp: 8.934e-03 | Valid force: 4.470e-02
# ==========================================================================================
# Running architecture: mlp_energy
#   model_cls               : ScalarEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/mlp_energy__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# [FAILED] mlp_energy: convergence_failure
# ==========================================================================================
# Running architecture: icnn_energy
#   model_cls               : ScalarEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/icnn_energy__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# [FAILED] icnn_energy: convergence_failure
# ==========================================================================================
# Running architecture: chol_energy_baseline
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_energy_baseline__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 1.313e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.049e-01 | Valid disp: 2.681e-02 | Valid force: 7.813e-01
# Epoch 100 | Train total: 1.026e-01 | Train disp: 1.542e-02 | Train force: 8.176e-01 | Valid total: 7.941e-02 | Valid disp: 1.326e-02 | Valid force: 6.615e-01
# Epoch 200 | Train total: 8.789e-02 | Train disp: 1.158e-02 | Train force: 7.071e-01 | Valid total: 6.614e-02 | Valid disp: 9.906e-03 | Valid force: 5.624e-01
# Epoch 300 | Train total: 7.940e-02 | Train disp: 1.010e-02 | Train force: 6.322e-01 | Valid total: 5.793e-02 | Valid disp: 8.495e-03 | Valid force: 4.944e-01
# Epoch 400 | Train total: 7.456e-02 | Train disp: 9.500e-03 | Train force: 5.933e-01 | Valid total: 5.378e-02 | Valid disp: 7.906e-03 | Valid force: 4.588e-01
# ==========================================================================================
# Running architecture: chol_energy_mlp
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_energy_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 1.313e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.049e-01 | Valid disp: 2.681e-02 | Valid force: 7.813e-01
# Epoch 100 | Train total: 9.903e-02 | Train disp: 1.454e-02 | Train force: 7.900e-01 | Valid total: 7.559e-02 | Valid disp: 1.239e-02 | Valid force: 6.320e-01
# Epoch 200 | Train total: 8.059e-02 | Train disp: 1.055e-02 | Train force: 6.422e-01 | Valid total: 5.825e-02 | Valid disp: 9.048e-03 | Valid force: 4.920e-01
# Epoch 300 | Train total: 7.178e-02 | Train disp: 9.415e-03 | Train force: 5.608e-01 | Valid total: 4.937e-02 | Valid disp: 8.023e-03 | Valid force: 4.135e-01
# Epoch 400 | Train total: 6.693e-02 | Train disp: 9.091e-03 | Train force: 5.200e-01 | Valid total: 4.573e-02 | Valid disp: 7.710e-03 | Valid force: 3.802e-01
# ==========================================================================================
# Running architecture: chol_energy_icnn
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_energy_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 1.038e-01 | Train disp: 2.322e-02 | Train force: 7.646e-01 | Valid total: 6.824e-02 | Valid disp: 1.569e-02 | Valid force: 5.255e-01
# Epoch 100 | Train total: 3.211e-02 | Train disp: 7.688e-03 | Train force: 1.581e-01 | Valid total: 1.270e-02 | Valid disp: 7.082e-03 | Valid force: 5.614e-02
# Epoch 200 | Train total: 3.073e-02 | Train disp: 7.720e-03 | Train force: 1.490e-01 | Valid total: 1.292e-02 | Valid disp: 7.334e-03 | Valid force: 5.585e-02
# Epoch 300 | Train total: 3.066e-02 | Train disp: 7.730e-03 | Train force: 1.470e-01 | Valid total: 1.303e-02 | Valid disp: 7.386e-03 | Valid force: 5.644e-02
# Epoch 400 | Train total: 2.991e-02 | Train disp: 7.715e-03 | Train force: 1.461e-01 | Valid total: 1.298e-02 | Valid disp: 7.380e-03 | Valid force: 5.604e-02
# Early stopping at epoch 424 | Best epoch: 224 | Best valid: 1.286e-02
# ==========================================================================================
# Running architecture: diag_stiffness_mlp
#   model_cls               : DiagonalPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_stiffness_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 2.830e+01 | Train disp: 4.710e-03 | Train force: 2.687e+02 | Valid total: 1.991e+01 | Valid disp: 2.300e-03 | Valid force: 1.991e+02
# Epoch 100 | Train total: 2.598e+01 | Train disp: 4.690e-03 | Train force: 2.465e+02 | Valid total: 1.827e+01 | Valid disp: 2.283e-03 | Valid force: 1.827e+02
# Epoch 200 | Train total: 2.383e+01 | Train disp: 4.674e-03 | Train force: 2.260e+02 | Valid total: 1.678e+01 | Valid disp: 2.271e-03 | Valid force: 1.678e+02
# Epoch 300 | Train total: 2.243e+01 | Train disp: 4.670e-03 | Train force: 2.124e+02 | Valid total: 1.584e+01 | Valid disp: 2.268e-03 | Valid force: 1.584e+02
# Epoch 400 | Train total: 2.165e+01 | Train disp: 4.670e-03 | Train force: 2.050e+02 | Valid total: 1.535e+01 | Valid disp: 2.269e-03 | Valid force: 1.535e+02
# ==========================================================================================
# Running architecture: diag_stiffness_icnn
#   model_cls               : DiagonalPlusStiffnessNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_stiffness_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 3.060e+02 | Train disp: 5.142e-03 | Train force: 2.932e+03 | Valid total: 1.844e+02 | Valid disp: 2.669e-03 | Valid force: 1.844e+03
# Epoch 100 | Train total: 9.400e+00 | Train disp: 4.743e-03 | Train force: 7.481e+01 | Valid total: 8.073e+00 | Valid disp: 2.373e-03 | Valid force: 8.071e+01
# [FAILED] diag_stiffness_icnn: convergence_failure
# ==========================================================================================
# Running architecture: chol_stiffness_mlp
#   model_cls               : CholeskyPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_stiffness_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 2.830e+01 | Train disp: 4.710e-03 | Train force: 2.687e+02 | Valid total: 1.991e+01 | Valid disp: 2.299e-03 | Valid force: 1.991e+02
# Epoch 100 | Train total: 2.576e+01 | Train disp: 4.589e-03 | Train force: 2.445e+02 | Valid total: 1.812e+01 | Valid disp: 2.197e-03 | Valid force: 1.812e+02
# Epoch 200 | Train total: 2.348e+01 | Train disp: 4.527e-03 | Train force: 2.226e+02 | Valid total: 1.655e+01 | Valid disp: 2.148e-03 | Valid force: 1.654e+02
# Epoch 300 | Train total: 2.201e+01 | Train disp: 4.502e-03 | Train force: 2.084e+02 | Valid total: 1.556e+01 | Valid disp: 2.131e-03 | Valid force: 1.556e+02
# Epoch 400 | Train total: 2.120e+01 | Train disp: 4.496e-03 | Train force: 2.006e+02 | Valid total: 1.505e+01 | Valid disp: 2.127e-03 | Valid force: 1.504e+02
# ==========================================================================================
# Running architecture: chol_stiffness_icnn
#   model_cls               : CholeskyPlusStiffnessNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 500
#   lr                      : 0.001
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 20
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0001
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : True
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_stiffness_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train total: 3.060e+02 | Train disp: 5.142e-03 | Train force: 2.932e+03 | Valid total: 1.844e+02 | Valid disp: 2.669e-03 | Valid force: 1.844e+03
# Epoch 100 | Train total: 9.305e+00 | Train disp: 4.629e-03 | Train force: 7.394e+01 | Valid total: 8.015e+00 | Valid disp: 2.276e-03 | Valid force: 8.013e+01
# Epoch 200 | Train total: 5.227e+00 | Train disp: 9.456e-02 | Train force: 3.864e+01 | Valid total: 4.514e+00 | Valid disp: 2.442e-03 | Valid force: 4.512e+01
# Epoch 300 | Train total: 3.987e+00 | Train disp: 1.621e-01 | Train force: 2.831e+01 | Valid total: 3.409e+00 | Valid disp: 8.630e-02 | Valid force: 3.323e+01
# [FAILED] chol_stiffness_icnn: convergence_failure
# Succeeded: 8/12
# Failures:
#   - mlp_energy: convergence_failure
#   - icnn_energy: convergence_failure
#   - diag_stiffness_icnn: convergence_failure
#   - chol_stiffness_icnn: convergence_failure

# %%
from architecture_plots import plot_architecture_comparison_paper, plot_summary_final_losses

PAPER_PLOT_DIR.mkdir(parents=True, exist_ok=True)

# Paper-ready PDF comparisons across all successfully completed architectures.
paper_architectures = successes if "successes" in globals() else selected_architectures
paper_paths = plot_architecture_comparison_paper(
    architectures=paper_architectures,
    results_dir=str(OUTPUT_DIR),
    output_dir=str(PAPER_PLOT_DIR),
    traj_idx=0,
)

# Convenience PNG summary of final losses from the in-memory results dict.
plot_summary_final_losses(
    {name: results[name] for name in paper_architectures},
    save_path=str(PAPER_PLOT_DIR / "final_loss_summary.png"),
    show=False,
)

print("Paper-ready plots written to:", PAPER_PLOT_DIR.resolve())
for key, path in paper_paths.items():
    if key != "colors":
        print(f"  {key}: {path}")
# Out:
# Paper-ready plots written to: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/paper_ready_architecture_comparison
#   training_loss: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/paper_ready_architecture_comparison/training_loss_comparison.pdf
#   validation_loss: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/paper_ready_architecture_comparison/validation_loss_comparison.pdf
#   training_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/paper_ready_architecture_comparison/training_trajectory_comparison.pdf
#   validation_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/paper_ready_architecture_comparison/validation_trajectory_comparison.pdf
#   training_xz_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/paper_ready_architecture_comparison/training_xz_trajectory_comparison.pdf
#   validation_xz_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/paper_ready_architecture_comparison/validation_xz_trajectory_comparison.pdf
#   combined_xz_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/paper_ready_architecture_comparison/combined_xz_trajectory_comparison.pdf

# %%
import subprocess
import sys

# Post-training Hessian diagnostics. This is intentionally separated from
# training so the architecture sweep stays fast.
HESSIAN_USE_PREDICTED = True
HESSIAN_STRIDE = 10
HESSIAN_MAX_TRAJECTORIES = 1  # set to None to process all trajectories
HESSIAN_SPLITS = ("train", "valid")

cmd = [
    sys.executable,
    "compute_architecture_hessian_diagnostics.py",
    str(OUTPUT_DIR),
    "--stride",
    str(HESSIAN_STRIDE),
    "--splits",
    *HESSIAN_SPLITS,
]
if HESSIAN_USE_PREDICTED:
    cmd.append("--use-predicted")
if HESSIAN_MAX_TRAJECTORIES is None:
    cmd.append("--all-trajectories")
else:
    cmd.extend(["--max-trajectories", str(HESSIAN_MAX_TRAJECTORIES)])

print("Running:", " ".join(cmd))
subprocess.run(cmd, cwd=str(ROOT), check=True)
print("Hessian diagnostics written into each architecture directory under:", OUTPUT_DIR.resolve())
# Out:
# Running: /Users/radha/GitRepos/dismech-jax/.venv/bin/python compute_architecture_hessian_diagnostics.py /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True --stride 10 --splits train valid --use-predicted --max-trajectories 1
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_energy_baseline__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1 | train: M=1.891e-01, kappa=4.384e+00, states=15 | valid: M=2.017e-01, kappa=4.499e+00, states=15
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_energy_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1 | train: M=2.202e-01, kappa=3.845e+00, states=15 | valid: M=2.350e-01, kappa=3.935e+00, states=15
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_energy_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1 | train: M=1.915e-01, kappa=4.351e+00, states=15 | valid: M=2.041e-01, kappa=4.465e+00, states=15
# [skip] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_stiffness_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1: missing config.json or model.eqx
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/chol_stiffness_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1 | train: M=8.243e-02, kappa=1.158e+01, states=15 | valid: M=9.507e-02, kappa=1.332e+01, states=15
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_energy_baseline__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1 | train: M=2.624e-01, kappa=6.153e+00, states=15 | valid: M=2.658e-01, kappa=6.407e+00, states=15
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_energy_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1 | train: M=2.359e-01, kappa=4.685e+00, states=15 | valid: M=2.451e-01, kappa=4.847e+00, states=15
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_energy_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1 | train: M=2.578e-01, kappa=5.890e+00, states=15 | valid: M=2.608e-01, kappa=6.127e+00, states=15
# [skip] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_stiffness_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1: missing config.json or model.eqx
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/diag_stiffness_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1 | train: M=6.527e-02, kappa=8.930e+00, states=15 | valid: M=7.098e-02, kappa=9.644e+00, states=15
# [skip] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/icnn_energy__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1: missing config.json or model.eqx
# [skip] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/mlp_energy__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_42__mdl_0.01__it_20__hreg_0.0001__hprobe_1__hseed_0__floss_0.1__fcomp_0__fsign_1: missing config.json or model.eqx
# Wrote Hessian diagnostics table with 16 rows to /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True/hessian_diagnostics_table.csv
# Finished Hessian diagnostics for 8/12 runs.
# Hessian diagnostics written into each architecture directory under: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True

# %%
print("All artifacts are organized under:")
print(" ", OUTPUT_DIR.resolve())
print("\nMain subfolders/files to inspect:")
print("  - <architecture>/results.npz")
print("  - <architecture>/model.eqx")
print("  - <architecture>/loss_curves.png")
print("  - <architecture>/pred_vs_truth_*")
print("  - <architecture>/force_pred_vs_truth_*.png")
print("  - <architecture>/energy_landscapes/")
print("  - <architecture>/hessian_diagnostics_*.npz")
print("  - <architecture>/hessian_diagnostics_summary.json")
print("  - paper_ready_architecture_comparison/*.pdf")
# Out:
# All artifacts are organized under:
#   /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n3_slinky_sim_all_architectures_fail_on_nonconvergence_True
#
# Main subfolders/files to inspect:
#   - <architecture>/results.npz
#   - <architecture>/model.eqx
#   - <architecture>/loss_curves.png
#   - <architecture>/pred_vs_truth_*
#   - <architecture>/force_pred_vs_truth_*.png
#   - <architecture>/energy_landscapes/
#   - <architecture>/hessian_diagnostics_*.npz
#   - <architecture>/hessian_diagnostics_summary.json
#   - paper_ready_architecture_comparison/*.pdf

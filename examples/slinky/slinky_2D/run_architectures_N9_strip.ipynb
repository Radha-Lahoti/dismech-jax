# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from properties import *

# %%
train_file = "../experiment_data/n9_strip_train_dataset.npz"
valid_file = "../experiment_data/n9_strip_test_dataset.npz"

# %%
from run_architectures import *

dir = "arch_sweep_outputs_all12_n9strip_run2"

cfg = SweepConfig(
    der_K_diag=(20, 0.002),
    der_K_chol=(20, 0.0, 0.002),
    hidden=(10,),
    corr_factor=0.1,
    input_mode="raw",
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=1e-2,
    seed=0,
    output_dir=dir,
)


# Example: choose only selected architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     # "chol_stiffness_mlp",
#     # add whatever you want here
# ]

# %%
# selected_architectures = subset_all()  # run all architectures

# remove certain architectures 
# selected_architectures = [
#     arch for arch in selected_architectures
#     if arch not in ["mlp_energy", "chol_stiffness_signed_mlp", "diag_stiffness_icnn", "chol_stiffness_icnn", "chol_stiffness_signed_icnn"]
# ]

selected_architectures = [
    "diag_energy_baseline",
    "diag_energy_icnn",
    "chol_energy_baseline",
    "chol_energy_icnn",
]

# %%
results = run_architecture_sweep(
    properties=StripN9Properties(),
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)
# Out:
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_run2/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.310e-03 | Valid: 6.419e-04
# Epoch 100 | Train: 1.193e-03 | Valid: 5.651e-04
# Epoch 200 | Train: 1.188e-03 | Valid: 5.597e-04
# Epoch 300 | Train: 1.188e-03 | Valid: 5.598e-04
# Epoch 400 | Train: 1.188e-03 | Valid: 5.598e-04
# /Users/piyushjirwankar/Radha-fork/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:193: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# ==========================================================================================
# Running architecture: diag_energy_mlp
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_run2/diag_energy_mlp__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.310e-03 | Valid: 6.419e-04
# Epoch 100 | Train: 5.302e-04 | Valid: 5.081e-04
# Epoch 200 | Train: 5.342e-04 | Valid: 5.708e-04
# Epoch 300 | Train: 6.493e-04 | Valid: 1.018e-03
# Epoch 400 | Train: 6.509e-04 | Valid: 7.445e-04
# ==========================================================================================
# Running architecture: diag_energy_icnn
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_run2/diag_energy_icnn__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.288e-03 | Valid: 7.360e-04
# Epoch 100 | Train: 4.750e-04 | Valid: 1.516e-03
# Epoch 200 | Train: 3.906e-04 | Valid: 6.153e-04
# Epoch 300 | Train: 3.856e-04 | Valid: 9.233e-04
# Epoch 400 | Train: 3.837e-04 | Valid: 7.519e-04
# ==========================================================================================
# Running architecture: icnn_energy
#   model_cls               : ScalarEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_run2/icnn_energy__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: nan | Valid: nan
# Epoch 100 | Train: nan | Valid: nan
# Epoch 200 | Train: nan | Valid: nan
# Epoch 300 | Train: nan | Valid: nan
# Epoch 400 | Train: nan | Valid: nan
# ==========================================================================================
# Running architecture: chol_energy_baseline
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_run2/chol_energy_baseline__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.310e-03 | Valid: 9.176e-04
# Epoch 100 | Train: 7.778e-04 | Valid: 1.128e-03
# Epoch 200 | Train: 7.538e-04 | Valid: 7.269e-04
# Epoch 300 | Train: 7.833e-04 | Valid: 6.567e-04
# Epoch 400 | Train: 6.922e-04 | Valid: 6.683e-04
# ==========================================================================================
# Running architecture: chol_energy_mlp
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_run2/chol_energy_mlp__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.310e-03 | Valid: 9.173e-04
# Epoch 100 | Train: 5.071e-04 | Valid: 7.630e-04
# Epoch 200 | Train: 3.955e-04 | Valid: 2.358e-02
# Epoch 300 | Train: 3.795e-04 | Valid: 2.320e-02
# Epoch 400 | Train: 3.773e-04 | Valid: 2.364e-02
# ==========================================================================================
# Running architecture: chol_energy_icnn
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_run2/chol_energy_icnn__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.288e-03 | Valid: 8.590e-04
# Epoch 100 | Train: 4.508e-04 | Valid: 3.559e-04
# Epoch 200 | Train: 4.109e-04 | Valid: 5.315e-04
# Epoch 300 | Train: 3.946e-04 | Valid: 8.106e-04
# Epoch 400 | Train: 3.906e-04 | Valid: 1.627e-03
# ==========================================================================================
# Running architecture: diag_stiffness_mlp
#   model_cls               : DiagonalPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_run2/diag_stiffness_mlp__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.290e-03 | Valid: 3.008e-02
# Epoch 100 | Train: 3.627e-02 | Valid: 2.927e-02
# Epoch 200 | Train: 2.496e-03 | Valid: 2.957e-02
# Epoch 300 | Train: 2.125e-02 | Valid: 2.941e-02
# Epoch 400 | Train: 2.731e-03 | Valid: 2.943e-02
# ==========================================================================================
# Running architecture: chol_stiffness_mlp
#   model_cls               : CholeskyPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10,)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.1
#   zero_reference          : True
#   seed                    : 0
#   max_dlambda             : 0.01
#   iters                   : 5
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_all12_n9strip_run2/chol_stiffness_mlp__hid_10__inp_raw__act_tanh__corr_0.1__zr1__seed_0__mdl_0.01__it_5
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.391e-02 | Valid: 2.190e-02
# Epoch 100 | Train: 2.327e-02 | Valid: 3.011e-02
# Epoch 200 | Train: 1.049e-01 | Valid: 9.396e-02
# Epoch 300 | Train: 3.655e-02 | Valid: 2.808e-02
# Epoch 400 | Train: 3.552e-02 | Valid: 2.728e-02

# %%
from architecture_plots import plot_architecture_comparison_paper


plot_architecture_comparison_paper(
    architectures=selected_architectures,
    # architectures=subset_all(),
    results_dir=dir,
    traj_idx=0,
)
# Out:
# {'training_loss': 'arch_sweep_outputs_all12_n9strip_run2/paper_ready_architecture_comparison/training_loss_comparison.pdf',
#  'validation_loss': 'arch_sweep_outputs_all12_n9strip_run2/paper_ready_architecture_comparison/validation_loss_comparison.pdf',
#  'training_trajectory': 'arch_sweep_outputs_all12_n9strip_run2/paper_ready_architecture_comparison/training_trajectory_comparison.pdf',
#  'validation_trajectory': 'arch_sweep_outputs_all12_n9strip_run2/paper_ready_architecture_comparison/validation_trajectory_comparison.pdf',
#  'colors': {'diag_energy_baseline': array([0.12156863, 0.46666667, 0.70588235, 1.        ]),
#   'diag_energy_icnn': array([0.83921569, 0.15294118, 0.15686275, 1.        ]),
#   'chol_energy_baseline': array([0.96862745, 0.71372549, 0.82352941, 1.        ]),
#   'chol_energy_icnn': array([0.61960784, 0.85490196, 0.89803922, 1.        ])}}

# %%
# from architecture_plots import plot_saved_results

# results_path = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/results.npz"
# plot_output_dir = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/replotted"


# plot_saved_results(
#     results_path=results_path,
#     output_dir=plot_output_dir, # if output_dir = None, image will just be shown and not saved
#     show=True,
#     make_component_plots=True,
# )

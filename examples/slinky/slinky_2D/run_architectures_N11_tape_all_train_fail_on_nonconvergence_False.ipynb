# %% [markdown]
# # N11 Tape Architecture Sweep
#
# Runs the tape architecture comparison using the core settings from `2d_tape_ICNN.ipynb`. Outputs include per-run artifacts, paper-ready architecture comparison plots, regenerated energy landscapes, and post-training Hessian diagnostics.

# %%
import os
from pathlib import Path

import jax
import jax.numpy as jnp

jax.config.update("jax_enable_x64", True)
os.environ.setdefault("XLA_PYTHON_CLIENT_PREALLOCATE", "false")

from properties import TapeN11Properties
from run_architectures import SweepConfig

ROOT = Path.cwd()
train_file = "../experiment_data/tape_data/11_noded/n11_tape_train_dataset.npz"
valid_file = "../experiment_data/tape_data/11_noded/n11_tape_test_dataset.npz"
properties = TapeN11Properties(mass=-0.005)

# Copied from 2d_tape_ICNN.ipynb
K_init_chol = (0.2, 0.0, 0.1)
K_init_diag = (0.2, 0.1)

base_cfg = SweepConfig(
    der_K_diag=K_init_diag,
    der_K_chol=K_init_chol,
    hidden=(10,),
    corr_factor=0.01,
    input_mode="raw",
    only_stretching_NN=False,
    only_bending_NN=False,
    zero_reference=True,
    activation="tanh",
    mode="anisotropic",
    n_epochs=1000,
    lr=5e-2,
    weight_decay=1e-5,
    seed=42,
    valid_every=10,
    max_dlambda=5e-2,
    iters=10,
    ls_steps=10,
    abs_tol=5e-4,
    rel_tol=1e-4,
    early_stop=True,
    train_fail_on_nonconvergence=False,
    prediction_fail_on_nonconvergence=False,
    hessian_reg_strength=1e-6,
    hessian_reg_probes=1,
    hessian_reg_seed=0,
    force_key=None,
    force_loss_strength=0.0,
    force_components=(0, 1, 2),
    force_sign=1.0,
    return_loss_components=False,
    early_stopping=True,
    early_stopping_patience=200,
    early_stopping_min_delta=1e-5,
    early_stopping_warmup_epochs=200,
    restore_best_model=True,
    save_npz=True,
    save_model=True,
    save_plots=True,
    save_force_predictions=False,
    plot_force_predictions=False,
    save_hessian_diagnostics=False,
    save_energy_landscapes=False,
    verbose=True,
    continue_on_failure=True,
)

print(properties)

OUTPUT_DIR = ROOT / "arch_sweep_outputs_n11_tape_all_architectures_train_fail_on_nonconvergence_False"
PAPER_PLOT_DIR = OUTPUT_DIR / "paper_ready_architecture_comparison"
base_cfg = base_cfg.__class__(**{**base_cfg.__dict__, "output_dir": str(OUTPUT_DIR)})
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"Saving architecture sweep results under: {OUTPUT_DIR.resolve()}")
# Out:
# TapeN11Properties(length=None, r0=0.005, axs=None, jxs=None, ixs1=None, ixs2=None, density=600.0, E=1000000.0, N=11, start=Array([0., 0., 0.], dtype=float64), end=Array([1.05660479, 0.        , 0.04239192], dtype=float64), mass=-0.005)
# Saving architecture sweep results under: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures

# %%
from run_architectures import subset_tape_tube_candidates, subset_brazier_stiffness_only

selected_architectures = subset_tape_tube_candidates()

# For a quicker debug pass, use only the models closest to 2d_tape_ICNN.ipynb:
# selected_architectures = [
#     "brazier_chol_stiffness_baseline",
#     "brazier_chol_stiffness_mlp",
#     "brazier_chol_stiffness_icnn",
# ]

print(f"Running {len(selected_architectures)} architectures:")
for name in selected_architectures:
    print(f"  - {name}")
print("\nPer-architecture plots:", base_cfg.save_plots)
print("Energy landscape snapshots during training:", base_cfg.save_energy_landscapes)
# Out:
# Running 14 architectures:
#   - diag_energy_baseline
#   - diag_energy_mlp
#   - diag_energy_icnn
#   - mlp_energy
#   - icnn_energy
#   - chol_energy_baseline
#   - chol_energy_mlp
#   - chol_energy_icnn
#   - brazier_diag_stiffness_baseline
#   - brazier_diag_stiffness_mlp
#   - brazier_diag_stiffness_icnn
#   - brazier_chol_stiffness_baseline
#   - brazier_chol_stiffness_mlp
#   - brazier_chol_stiffness_icnn
#
# Per-architecture plots: True
# Energy landscape snapshots during training: False

# %%
from run_architectures import run_architecture_sweep

results = run_architecture_sweep(
    properties=properties,
    train_file=train_file,
    valid_file=valid_file,
    cfg=base_cfg,
    selected_architectures=selected_architectures,
)

successes = [name for name, result in results.items() if result["success"]]
failures = {name: result["failure_reason"] for name, result in results.items() if not result["success"]}

print(f"Succeeded: {len(successes)}/{len(results)}")
if failures:
    print("Failures:")
    for name, reason in failures.items():
        print(f"  - {name}: {reason}")
else:
    print("No architecture failures.")
# Out:
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/diag_energy_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05
# ==========================================================================================
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/util.py:664: RuntimeWarning: Mass is non-positive; if this is because gravity is in +z, ignore, but if this is not the intention please correct.
#   base, aux = get_slinky(properties)
# Epoch 000 | Train total: 2.305e-02 | Train disp: 1.911e-02 | Train force: 0.000e+00 | Valid total: 2.782e-02 | Valid disp: 2.782e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 8.930e-03 | Train disp: 7.278e-03 | Train force: 0.000e+00 | Valid total: 1.069e-02 | Valid disp: 1.069e-02 | Valid force: 0.000e+00
# Epoch 200 | Train total: 8.655e-03 | Train disp: 7.364e-03 | Train force: 0.000e+00 | Valid total: 1.083e-02 | Valid disp: 1.083e-02 | Valid force: 0.000e+00
# Early stopping at epoch 220 | Best epoch: 020 | Best valid: 7.534e-03
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/run_architectures.py:1038: RuntimeWarning: Mass is non-positive; if this is because gravity is in +z, ignore, but if this is not the intention please correct.
#   base, aux = get_slinky(properties)
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:234: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# ==========================================================================================
# Running architecture: diag_energy_mlp
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/diag_energy_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05
# ==========================================================================================
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/util.py:664: RuntimeWarning: Mass is non-positive; if this is because gravity is in +z, ignore, but if this is not the intention please correct.
#   base, aux = get_slinky(properties)
# Epoch 000 | Train total: 2.305e-02 | Train disp: 1.911e-02 | Train force: 0.000e+00 | Valid total: 2.744e-02 | Valid disp: 2.744e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 5.197e-03 | Train disp: 4.429e-03 | Train force: 0.000e+00 | Valid total: 1.193e-02 | Valid disp: 1.193e-02 | Valid force: 0.000e+00
# Epoch 200 | Train total: 4.655e-03 | Train disp: 4.100e-03 | Train force: 0.000e+00 | Valid total: 1.202e-02 | Valid disp: 1.202e-02 | Valid force: 0.000e+00
# Early stopping at epoch 210 | Best epoch: 010 | Best valid: 5.833e-03
# ==========================================================================================
# Running architecture: diag_energy_icnn
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/diag_energy_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05
# ==========================================================================================
# Epoch 000 | Train total: 2.301e-02 | Train disp: 1.906e-02 | Train force: 0.000e+00 | Valid total: 1.785e-02 | Valid disp: 1.785e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 6.305e-03 | Train disp: 5.518e-03 | Train force: 0.000e+00 | Valid total: 9.359e-03 | Valid disp: 9.359e-03 | Valid force: 0.000e+00
# Epoch 200 | Train total: 6.079e-03 | Train disp: 5.530e-03 | Train force: 0.000e+00 | Valid total: 9.255e-03 | Valid disp: 9.255e-03 | Valid force: 0.000e+00
# Early stopping at epoch 240 | Best epoch: 040 | Best valid: 8.886e-03
# ==========================================================================================
# Running architecture: mlp_energy
#   model_cls               : ScalarEnergyNN
#   which_case              : MLP
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/mlp_energy__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05
# ==========================================================================================
# [FAILED] mlp_energy: convergence_failure
# ==========================================================================================
# Running architecture: icnn_energy
#   model_cls               : ScalarEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/icnn_energy__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05
# ==========================================================================================
# [FAILED] icnn_energy: convergence_failure
# ==========================================================================================
# Running architecture: chol_energy_baseline
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/chol_energy_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05
# ==========================================================================================
# Epoch 000 | Train total: 2.305e-02 | Train disp: 1.911e-02 | Train force: 0.000e+00 | Valid total: 2.274e-02 | Valid disp: 2.274e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 6.856e-03 | Train disp: 5.204e-03 | Train force: 0.000e+00 | Valid total: 1.254e-02 | Valid disp: 1.254e-02 | Valid force: 0.000e+00
# Epoch 200 | Train total: 6.572e-03 | Train disp: 5.269e-03 | Train force: 0.000e+00 | Valid total: 1.257e-02 | Valid disp: 1.257e-02 | Valid force: 0.000e+00
# Early stopping at epoch 220 | Best epoch: 020 | Best valid: 8.152e-03
# ==========================================================================================
# Running architecture: chol_energy_mlp
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/chol_energy_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05
# ==========================================================================================
# Epoch 000 | Train total: 2.305e-02 | Train disp: 1.911e-02 | Train force: 0.000e+00 | Valid total: 2.251e-02 | Valid disp: 2.251e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 4.820e-03 | Train disp: 4.086e-03 | Train force: 0.000e+00 | Valid total: 1.176e-02 | Valid disp: 1.176e-02 | Valid force: 0.000e+00
# Epoch 200 | Train total: 4.633e-03 | Train disp: 4.103e-03 | Train force: 0.000e+00 | Valid total: 1.220e-02 | Valid disp: 1.220e-02 | Valid force: 0.000e+00
# Early stopping at epoch 220 | Best epoch: 020 | Best valid: 8.767e-03
# ==========================================================================================
# Running architecture: chol_energy_icnn
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/chol_energy_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05
# ==========================================================================================
# Epoch 000 | Train total: 2.301e-02 | Train disp: 1.906e-02 | Train force: 0.000e+00 | Valid total: 1.576e-02 | Valid disp: 1.576e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 4.831e-03 | Train disp: 4.076e-03 | Train force: 0.000e+00 | Valid total: 1.369e-02 | Valid disp: 1.369e-02 | Valid force: 0.000e+00
# Epoch 200 | Train total: 4.678e-03 | Train disp: 4.102e-03 | Train force: 0.000e+00 | Valid total: 1.273e-02 | Valid disp: 1.273e-02 | Valid force: 0.000e+00
# Early stopping at epoch 230 | Best epoch: 030 | Best valid: 1.123e-02
# ==========================================================================================
# Running architecture: brazier_diag_stiffness_baseline
#   model_cls               : StructuredBrazierDiagonalEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_diag_stiffness_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic
# ==========================================================================================
# [FAILED] brazier_diag_stiffness_baseline: convergence_failure
# ==========================================================================================
# Running architecture: brazier_diag_stiffness_mlp
#   model_cls               : StructuredBrazierDiagonalEnergyNN
#   which_case              : MLP
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_diag_stiffness_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic
# ==========================================================================================
# Epoch 000 | Train total: 1.450e-01 | Train disp: 9.788e-03 | Train force: 0.000e+00 | Valid total: 1.158e-02 | Valid disp: 1.158e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 6.792e-02 | Train disp: 7.962e-03 | Train force: 0.000e+00 | Valid total: 8.918e-03 | Valid disp: 8.918e-03 | Valid force: 0.000e+00
# Epoch 200 | Train total: 3.519e-02 | Train disp: 7.737e-03 | Train force: 0.000e+00 | Valid total: 8.943e-03 | Valid disp: 8.943e-03 | Valid force: 0.000e+00
# Epoch 300 | Train total: 2.639e-02 | Train disp: 7.453e-03 | Train force: 0.000e+00 | Valid total: 8.683e-03 | Valid disp: 8.683e-03 | Valid force: 0.000e+00
# Epoch 400 | Train total: 2.576e-02 | Train disp: 7.253e-03 | Train force: 0.000e+00 | Valid total: 8.536e-03 | Valid disp: 8.536e-03 | Valid force: 0.000e+00
# Epoch 500 | Train total: 1.764e-02 | Train disp: 7.123e-03 | Train force: 0.000e+00 | Valid total: 8.467e-03 | Valid disp: 8.467e-03 | Valid force: 0.000e+00
# Epoch 600 | Train total: 1.589e-02 | Train disp: 7.032e-03 | Train force: 0.000e+00 | Valid total: 8.416e-03 | Valid disp: 8.416e-03 | Valid force: 0.000e+00
# Epoch 700 | Train total: 1.544e-02 | Train disp: 6.982e-03 | Train force: 0.000e+00 | Valid total: 8.431e-03 | Valid disp: 8.431e-03 | Valid force: 0.000e+00
# Epoch 800 | Train total: 1.600e-02 | Train disp: 6.951e-03 | Train force: 0.000e+00 | Valid total: 8.450e-03 | Valid disp: 8.450e-03 | Valid force: 0.000e+00
# Early stopping at epoch 820 | Best epoch: 620 | Best valid: 8.405e-03
# ==========================================================================================
# Running architecture: brazier_diag_stiffness_icnn
#   model_cls               : StructuredBrazierDiagonalEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_diag_stiffness_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic
# ==========================================================================================
# Epoch 000 | Train total: 1.546e-01 | Train disp: 9.732e-03 | Train force: 0.000e+00 | Valid total: 1.147e-02 | Valid disp: 1.147e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 1.240e-01 | Train disp: 7.960e-03 | Train force: 0.000e+00 | Valid total: 8.454e-03 | Valid disp: 8.454e-03 | Valid force: 0.000e+00
# Epoch 200 | Train total: 9.127e-02 | Train disp: 7.842e-03 | Train force: 0.000e+00 | Valid total: 8.295e-03 | Valid disp: 8.295e-03 | Valid force: 0.000e+00
# Epoch 300 | Train total: 8.559e-02 | Train disp: 7.759e-03 | Train force: 0.000e+00 | Valid total: 8.212e-03 | Valid disp: 8.212e-03 | Valid force: 0.000e+00
# Epoch 400 | Train total: 1.004e-01 | Train disp: 7.693e-03 | Train force: 0.000e+00 | Valid total: 8.146e-03 | Valid disp: 8.146e-03 | Valid force: 0.000e+00
# Epoch 500 | Train total: 6.875e-02 | Train disp: 7.643e-03 | Train force: 0.000e+00 | Valid total: 8.104e-03 | Valid disp: 8.104e-03 | Valid force: 0.000e+00
# Epoch 600 | Train total: 6.388e-02 | Train disp: 7.600e-03 | Train force: 0.000e+00 | Valid total: 8.073e-03 | Valid disp: 8.073e-03 | Valid force: 0.000e+00
# Epoch 700 | Train total: 6.554e-02 | Train disp: 7.574e-03 | Train force: 0.000e+00 | Valid total: 8.054e-03 | Valid disp: 8.054e-03 | Valid force: 0.000e+00
# Epoch 800 | Train total: 7.274e-02 | Train disp: 7.556e-03 | Train force: 0.000e+00 | Valid total: 8.049e-03 | Valid disp: 8.049e-03 | Valid force: 0.000e+00
# Epoch 900 | Train total: 7.326e-02 | Train disp: 7.541e-03 | Train force: 0.000e+00 | Valid total: 8.036e-03 | Valid disp: 8.036e-03 | Valid force: 0.000e+00
# ==========================================================================================
# Running architecture: brazier_chol_stiffness_baseline
#   model_cls               : StructuredBrazierCholeskyEnergyNN
#   which_case              : baseline
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_chol_stiffness_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic
# ==========================================================================================
# [FAILED] brazier_chol_stiffness_baseline: convergence_failure
# ==========================================================================================
# Running architecture: brazier_chol_stiffness_mlp
#   model_cls               : StructuredBrazierCholeskyEnergyNN
#   which_case              : MLP
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_chol_stiffness_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic
# ==========================================================================================
# Epoch 000 | Train total: 7.275e-02 | Train disp: 9.233e-03 | Train force: 0.000e+00 | Valid total: 1.127e-02 | Valid disp: 1.127e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 2.269e-02 | Train disp: 6.840e-03 | Train force: 0.000e+00 | Valid total: 9.264e-03 | Valid disp: 9.264e-03 | Valid force: 0.000e+00
# Epoch 200 | Train total: 1.171e-02 | Train disp: 5.666e-03 | Train force: 0.000e+00 | Valid total: 8.518e-03 | Valid disp: 8.518e-03 | Valid force: 0.000e+00
# Epoch 300 | Train total: 8.962e-03 | Train disp: 5.109e-03 | Train force: 0.000e+00 | Valid total: 9.121e-03 | Valid disp: 9.121e-03 | Valid force: 0.000e+00
# Epoch 400 | Train total: 8.725e-03 | Train disp: 4.908e-03 | Train force: 0.000e+00 | Valid total: 9.871e-03 | Valid disp: 9.871e-03 | Valid force: 0.000e+00
# Early stopping at epoch 400 | Best epoch: 200 | Best valid: 8.518e-03
# ==========================================================================================
# Running architecture: brazier_chol_stiffness_icnn
#   model_cls               : StructuredBrazierCholeskyEnergyNN
#   which_case              : ICNN
#   hidden                  : (10,)
#   input_mode              : raw
#   only_stretching_NN      : False
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   n_epochs                : 1000
#   lr                      : 0.05
#   weight_decay            : 1e-05
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0005
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : True
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 1e-06
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : None
#   force_loss_strength     : 0.0
#   force_components        : (0, 1, 2)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_chol_stiffness_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic
# ==========================================================================================
# Epoch 000 | Train total: 8.180e-02 | Train disp: 1.039e-02 | Train force: 0.000e+00 | Valid total: 1.207e-02 | Valid disp: 1.207e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 5.138e-02 | Train disp: 9.971e-03 | Train force: 0.000e+00 | Valid total: 1.293e-02 | Valid disp: 1.293e-02 | Valid force: 0.000e+00
# Epoch 200 | Train total: 3.301e-02 | Train disp: 8.558e-03 | Train force: 0.000e+00 | Valid total: 1.188e-02 | Valid disp: 1.188e-02 | Valid force: 0.000e+00
# Epoch 300 | Train total: 2.964e-02 | Train disp: 6.426e-03 | Train force: 0.000e+00 | Valid total: 8.150e-03 | Valid disp: 8.150e-03 | Valid force: 0.000e+00
# Epoch 400 | Train total: 3.059e-02 | Train disp: 5.885e-03 | Train force: 0.000e+00 | Valid total: 7.239e-03 | Valid disp: 7.239e-03 | Valid force: 0.000e+00
# Epoch 500 | Train total: 1.971e-02 | Train disp: 5.574e-03 | Train force: 0.000e+00 | Valid total: 6.170e-03 | Valid disp: 6.170e-03 | Valid force: 0.000e+00
# Epoch 600 | Train total: 1.772e-02 | Train disp: 5.264e-03 | Train force: 0.000e+00 | Valid total: 5.971e-03 | Valid disp: 5.971e-03 | Valid force: 0.000e+00
# Epoch 700 | Train total: 1.786e-02 | Train disp: 5.121e-03 | Train force: 0.000e+00 | Valid total: 5.728e-03 | Valid disp: 5.728e-03 | Valid force: 0.000e+00
# Epoch 800 | Train total: 1.987e-02 | Train disp: 5.004e-03 | Train force: 0.000e+00 | Valid total: 6.799e-03 | Valid disp: 6.799e-03 | Valid force: 0.000e+00
# Epoch 900 | Train total: 1.782e-02 | Train disp: 4.951e-03 | Train force: 0.000e+00 | Valid total: 5.813e-03 | Valid disp: 5.813e-03 | Valid force: 0.000e+00
# Early stopping at epoch 910 | Best epoch: 710 | Best valid: 5.613e-03
# Succeeded: 10/14
# Failures:
#   - mlp_energy: convergence_failure
#   - icnn_energy: convergence_failure
#   - brazier_diag_stiffness_baseline: convergence_failure
#   - brazier_chol_stiffness_baseline: convergence_failure

# %%
from run_architectures import generate_energy_landscapes_for_sweep

energy_landscape_paths = generate_energy_landscapes_for_sweep(
    str(OUTPUT_DIR),
    architectures=successes if "successes" in globals() else selected_architectures,
    include_initial=False,
    include_final=True,
    use_valid=True,
    traj_idx=0,
    dpi=180,
    n_grid=None,
    continue_on_failure=True,
)
print("Energy landscape plots regenerated for", len(energy_landscape_paths), "runs.")
# Out:
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/run_architectures.py:797: RuntimeWarning: Mass is non-positive; if this is because gravity is in +z, ignore, but if this is not the intention please correct.
#   base, aux = get_slinky(properties)
# [ok] brazier_chol_stiffness_icnn: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_chol_stiffness_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic/energy_landscapes/energy_landscape_final.png'}
# [ok] brazier_chol_stiffness_mlp: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_chol_stiffness_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic/energy_landscapes/energy_landscape_final.png'}
# [ok] brazier_diag_stiffness_icnn: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_diag_stiffness_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic/energy_landscapes/energy_landscape_final.png'}
# [ok] brazier_diag_stiffness_mlp: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_diag_stiffness_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic/energy_landscapes/energy_landscape_final.png'}
# [ok] chol_energy_baseline: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/chol_energy_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05/energy_landscapes/energy_landscape_final.png'}
# [ok] chol_energy_icnn: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/chol_energy_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05/energy_landscapes/energy_landscape_final.png'}
# [ok] chol_energy_mlp: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/chol_energy_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05/energy_landscapes/energy_landscape_final.png'}
# [ok] diag_energy_baseline: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/diag_energy_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05/energy_landscapes/energy_landscape_final.png'}
# [ok] diag_energy_icnn: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/diag_energy_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05/energy_landscapes/energy_landscape_final.png'}
# [ok] diag_energy_mlp: {'final': '/Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/diag_energy_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05/energy_landscapes/energy_landscape_final.png'}
# Energy landscape plots regenerated for 10 runs.

# %%
from architecture_plots import plot_architecture_comparison_paper, plot_summary_final_losses

PAPER_PLOT_DIR.mkdir(parents=True, exist_ok=True)
paper_architectures = successes if "successes" in globals() else selected_architectures
paper_paths = plot_architecture_comparison_paper(
    architectures=paper_architectures,
    results_dir=str(OUTPUT_DIR),
    output_dir=str(PAPER_PLOT_DIR),
    traj_idx=0,
)
plot_summary_final_losses(
    {name: results[name] for name in paper_architectures},
    save_path=str(PAPER_PLOT_DIR / "final_loss_summary.png"),
    show=False,
)
print("Paper-ready plots written to:", PAPER_PLOT_DIR.resolve())
for key, path in paper_paths.items():
    if key != "colors":
        print(f"  {key}: {path}")
# Out:
# Paper-ready plots written to: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/paper_ready_architecture_comparison
#   training_loss: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/paper_ready_architecture_comparison/training_loss_comparison.pdf
#   validation_loss: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/paper_ready_architecture_comparison/validation_loss_comparison.pdf
#   training_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/paper_ready_architecture_comparison/training_trajectory_comparison.pdf
#   validation_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/paper_ready_architecture_comparison/validation_trajectory_comparison.pdf
#   training_xz_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/paper_ready_architecture_comparison/training_xz_trajectory_comparison.pdf
#   validation_xz_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/paper_ready_architecture_comparison/validation_xz_trajectory_comparison.pdf
#   combined_xz_trajectory: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/paper_ready_architecture_comparison/combined_xz_trajectory_comparison.pdf

# %%
import subprocess
import sys

HESSIAN_USE_PREDICTED = True
HESSIAN_STRIDE = 10
HESSIAN_MAX_TRAJECTORIES = 1
HESSIAN_SPLITS = ("train", "valid")

cmd = [
    sys.executable,
    "compute_architecture_hessian_diagnostics.py",
    str(OUTPUT_DIR),
    "--stride", str(HESSIAN_STRIDE),
    "--splits", *HESSIAN_SPLITS,
]
if HESSIAN_USE_PREDICTED:
    cmd.append("--use-predicted")
if HESSIAN_MAX_TRAJECTORIES is None:
    cmd.append("--all-trajectories")
else:
    cmd.extend(["--max-trajectories", str(HESSIAN_MAX_TRAJECTORIES)])

print("Running:", " ".join(cmd))
subprocess.run(cmd, cwd=str(ROOT), check=True)
print("Hessian diagnostics table:", OUTPUT_DIR / "hessian_diagnostics_table.csv")
# Out:
# Running: /Users/radha/GitRepos/dismech-jax/.venv/bin/python compute_architecture_hessian_diagnostics.py /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures --stride 10 --splits train valid --use-predicted --max-trajectories 1
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/compute_architecture_hessian_diagnostics.py:524: RuntimeWarning: Mass is non-positive; if this is because gravity is in +z, ignore, but if this is not the intention please correct.
#   base, aux = get_slinky(properties)
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_chol_stiffness_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic | train: M=6.411e+01, kappa=1.189e+04, states=2 | valid: M=3.378e+01, kappa=6.399e+03, states=2
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/compute_architecture_hessian_diagnostics.py:524: RuntimeWarning: Mass is non-positive; if this is because gravity is in +z, ignore, but if this is not the intention please correct.
#   base, aux = get_slinky(properties)
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_chol_stiffness_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic | train: M=7.656e+01, kappa=3.039e+04, states=2 | valid: M=4.616e+00, kappa=1.825e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_chol_stiffness_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic | train: M=2.511e+01, kappa=5.693e+03, states=2 | valid: M=1.362e+01, kappa=3.136e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_diag_stiffness_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic | train: M=4.693e+01, kappa=9.403e+03, states=2 | valid: M=2.486e+01, kappa=5.073e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_diag_stiffness_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic | train: M=7.589e+00, kappa=5.058e+03, states=2 | valid: M=4.070e+00, kappa=2.746e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/brazier_diag_stiffness_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05__mode_anisotropic | train: M=2.121e+01, kappa=5.891e+03, states=2 | valid: M=1.130e+01, kappa=3.193e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/chol_energy_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05 | train: M=4.773e+01, kappa=6.929e+03, states=2 | valid: M=2.602e+01, kappa=3.841e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/chol_energy_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05 | train: M=1.177e+01, kappa=1.168e+03, states=2 | valid: M=1.542e+01, kappa=1.425e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/chol_energy_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05 | train: M=3.510e+01, kappa=4.665e+03, states=2 | valid: M=1.148e+02, kappa=1.548e+04, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/diag_energy_baseline__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05 | train: M=3.968e+01, kappa=7.822e+03, states=2 | valid: M=2.100e+01, kappa=4.214e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/diag_energy_icnn__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05 | train: M=1.305e+01, kappa=1.310e+03, states=2 | valid: M=1.108e+01, kappa=1.065e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/diag_energy_mlp__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05 | train: M=9.097e+00, kappa=1.770e+03, states=2 | valid: M=1.245e+01, kappa=2.464e+03, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/icnn_energy__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05 | train: M=1.000e+12, kappa=2.258e+12, states=2 | valid: M=1.000e+12, kappa=1.238e+13, states=2
# [ok] /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/mlp_energy__hid_10__inp_raw__stretchNN_0__bendNN_0__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10__hreg_1e-06__hprobe_1__hseed_0__wd_1e-05 | train: M=1.000e+12, kappa=0.000e+00, states=2 | valid: M=1.000e+12, kappa=5.671e+10, states=2
# Wrote Hessian diagnostics table with 28 rows to /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/hessian_diagnostics_table.csv
# Finished Hessian diagnostics for 14/14 runs.
# Hessian diagnostics table: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/arch_sweep_outputs_n11_tape_all_architectures/hessian_diagnostics_table.csv

# %%
print("Done. Key outputs:")
print("  - <architecture>/results.npz")
print("  - <architecture>/model.eqx")
print("  - <architecture>/hessian_diagnostics_summary.json")
print("  - hessian_diagnostics_table.csv")
print("  - paper_ready_architecture_comparison/*.pdf")
# Out:
# Done. Key outputs:
#   - <architecture>/results.npz
#   - <architecture>/model.eqx
#   - <architecture>/hessian_diagnostics_summary.json
#   - hessian_diagnostics_table.csv
#   - paper_ready_architecture_comparison/*.pdf

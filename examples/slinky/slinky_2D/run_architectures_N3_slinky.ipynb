# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from properties import *

# %%
train_file = "../experiment_data/n3_slinky_train_dataset.npz"
valid_file = "../experiment_data/n3_slinky_test_dataset.npz"

# %%
from run_architectures import *
dir = "arch_sweep_outputs_run1_n3_slinky"

cfg = SweepConfig(
    der_K_diag=(0.02, 0.01),
    der_K_chol=(0.02, 0.0, 0.01),
    hidden=(10,10),
    corr_factor=0.01,
    input_mode="raw",
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=1e-2,
    seed=42,
    output_dir=dir,
    iters = 10,
    max_dlambda = 5e-2
)


# # Example: choose only selected architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     # "chol_stiffness_mlp",
#     # add whatever you want here
# ]
# selected_architectures = subset_all()  # run all architectures

# remove mlp_energy, chol_stiffness_signed_mlp, all stiffness_icnn from the plot since they are so bad that they throw off the scale and make it hard to see differences between the other architectures
# selected_architectures = [
#     arch for arch in subset_all()
#     if arch not in ["mlp_energy", "chol_stiffness_signed_mlp", "diag_stiffness_icnn", "chol_stiffness_icnn", "chol_stiffness_signed_icnn"]
# ]

# good architectures
selected_architectures = [
    "diag_energy_baseline",
    "chol_energy_baseline",
    "diag_energy_icnn",
    "chol_energy_icnn",
    "diag_energy_mlp",
    "chol_energy_mlp",
    "diag_stiffness_mlp",
    "chol_stiffness_mlp",
    # add whatever you want here
]

# %%
results = run_architecture_sweep(
    properties=SlinkyN3Properties(),
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)
# Out:
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run3_n3_slinky_run1/diag_energy_baseline__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 7.679e-04 | Valid: 3.413e-04
# Epoch 100 | Train: 3.016e-04 | Valid: 2.856e-04
# Epoch 200 | Train: 3.014e-04 | Valid: 2.839e-04
# Epoch 300 | Train: 3.014e-04 | Valid: 2.840e-04
# Epoch 400 | Train: 3.014e-04 | Valid: 2.841e-04
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:233: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# ==========================================================================================
# Running architecture: chol_energy_baseline
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run3_n3_slinky_run1/chol_energy_baseline__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 7.679e-04 | Valid: 2.135e-04
# Epoch 100 | Train: 2.990e-04 | Valid: 2.298e-04
# Epoch 200 | Train: 2.985e-04 | Valid: 2.392e-04
# Epoch 300 | Train: 2.985e-04 | Valid: 2.416e-04
# Epoch 400 | Train: 2.985e-04 | Valid: 2.421e-04
# ==========================================================================================
# Running architecture: diag_energy_icnn
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run3_n3_slinky_run1/diag_energy_icnn__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 7.087e-04 | Valid: 1.783e-04
# Epoch 100 | Train: 1.180e-04 | Valid: 1.580e-04
# Epoch 200 | Train: 4.265e-05 | Valid: 1.202e-04
# Epoch 300 | Train: 4.101e-05 | Valid: 1.182e-04
# Epoch 400 | Train: 4.047e-05 | Valid: 1.181e-04
# ==========================================================================================
# Running architecture: chol_energy_icnn
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run3_n3_slinky_run1/chol_energy_icnn__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 7.087e-04 | Valid: 2.156e-04
# Epoch 100 | Train: 1.315e-04 | Valid: 1.479e-04
# Epoch 200 | Train: 4.379e-05 | Valid: 1.140e-04
# Epoch 300 | Train: 4.101e-05 | Valid: 1.192e-04
# Epoch 400 | Train: 4.029e-05 | Valid: 1.200e-04
# ==========================================================================================
# Running architecture: diag_energy_mlp
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run3_n3_slinky_run1/diag_energy_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 7.679e-04 | Valid: 3.413e-04
# Epoch 100 | Train: 6.396e-05 | Valid: 1.822e-04
# Epoch 200 | Train: 5.390e-05 | Valid: 1.598e-04
# Epoch 300 | Train: 4.943e-05 | Valid: 1.516e-04
# Epoch 400 | Train: 4.672e-05 | Valid: 1.545e-04
# ==========================================================================================
# Running architecture: chol_energy_mlp
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run3_n3_slinky_run1/chol_energy_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 7.679e-04 | Valid: 2.135e-04
# Epoch 100 | Train: 5.554e-05 | Valid: 1.649e-04
# Epoch 200 | Train: 5.492e-05 | Valid: 1.623e-04
# Epoch 300 | Train: 5.392e-05 | Valid: 1.627e-04
# Epoch 400 | Train: 5.228e-05 | Valid: 1.593e-04
# ==========================================================================================
# Running architecture: diag_stiffness_mlp
#   model_cls               : DiagonalPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run3_n3_slinky_run1/diag_stiffness_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.894e-03 | Valid: 3.339e-03
# Epoch 100 | Train: 2.198e-03 | Valid: 2.920e-03
# Epoch 200 | Train: 2.820e-03 | Valid: 3.255e-03
# Epoch 300 | Train: 2.786e-03 | Valid: 3.229e-03
# Epoch 400 | Train: 2.750e-03 | Valid: 3.203e-03
# ==========================================================================================
# Running architecture: chol_stiffness_mlp
#   model_cls               : CholeskyPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run3_n3_slinky_run1/chol_stiffness_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.805e-03 | Valid: 3.243e-03
# Epoch 100 | Train: 9.589e-04 | Valid: 2.035e-03
# Epoch 200 | Train: 8.436e-04 | Valid: 1.847e-03
# Epoch 300 | Train: 7.765e-04 | Valid: 1.724e-03
# Epoch 400 | Train: 7.445e-04 | Valid: 1.661e-03

# %%
from architecture_plots import plot_architecture_comparison_paper
plot_dir = "arch_sweep_outputs_run1_n3_slinky"
# good architectures
plot_architectures = [
    "diag_energy_baseline",
    "chol_energy_baseline",
    "diag_energy_icnn",
    "chol_energy_icnn",
    # add whatever you want here
]

plot_architecture_comparison_paper(
    architectures=plot_architectures,
    # architectures=subset_all(),
    results_dir=plot_dir,
    traj_idx=2,
)
# Out:
# {'training_loss': 'arch_sweep_outputs_run1_n3_slinky/paper_ready_architecture_comparison/training_loss_comparison.pdf',
#  'validation_loss': 'arch_sweep_outputs_run1_n3_slinky/paper_ready_architecture_comparison/validation_loss_comparison.pdf',
#  'training_trajectory': 'arch_sweep_outputs_run1_n3_slinky/paper_ready_architecture_comparison/training_trajectory_comparison.pdf',
#  'validation_trajectory': 'arch_sweep_outputs_run1_n3_slinky/paper_ready_architecture_comparison/validation_trajectory_comparison.pdf',
#  'training_xz_trajectory': 'arch_sweep_outputs_run1_n3_slinky/paper_ready_architecture_comparison/training_xz_trajectory_comparison.pdf',
#  'validation_xz_trajectory': 'arch_sweep_outputs_run1_n3_slinky/paper_ready_architecture_comparison/validation_xz_trajectory_comparison.pdf',
#  'combined_xz_trajectory': 'arch_sweep_outputs_run1_n3_slinky/paper_ready_architecture_comparison/combined_xz_trajectory_comparison.pdf',
#  'colors': {'diag_energy_baseline': (np.float64(0.12156862745098039),
#    np.float64(0.4666666666666667),
#    np.float64(0.7058823529411765),
#    np.float64(1.0)),
#   'chol_energy_baseline': (np.float64(1.0),
#    np.float64(0.4980392156862745),
#    np.float64(0.054901960784313725),
#    np.float64(1.0)),
#   'diag_energy_icnn': (np.float64(0.17254901960784313),
#    np.float64(0.6274509803921569),
#    np.float64(0.17254901960784313),
#    np.float64(1.0)),
#   'chol_energy_icnn': (np.float64(0.8392156862745098),
#    np.float64(0.15294117647058825),
#    np.float64(0.1568627450980392),
#    np.float64(1.0))}}

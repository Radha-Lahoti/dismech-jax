# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from properties import *

# %%
train_file = "../experiment_data/n7_tube_train_dataset.npz"
valid_file = "../experiment_data/n7_tube_test_dataset.npz"

# %%
from run_architectures import *
dir = "arch_sweep_outputs_run1_n7_tube"

cfg = SweepConfig(
    der_K_diag=(0.2, 0.2),
    der_K_chol=(0.2, 0.0, 0.2),
    hidden=(10,10),
    corr_factor=0.01,
    input_mode="raw",
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=1e-2,
    seed=42,
    output_dir=dir,
    iters = 10,
    max_dlambda = 5e-2
)


# # Example: choose only selected architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     # "chol_stiffness_mlp",
#     # add whatever you want here
# ]
selected_architectures = subset_all()  # run all architectures

# remove mlp_energy, chol_stiffness_signed_mlp, all stiffness_icnn from the plot since they are so bad that they throw off the scale and make it hard to see differences between the other architectures
selected_architectures = [
    arch for arch in subset_all()
    if arch not in ["mlp_energy", "chol_stiffness_signed_mlp", "diag_stiffness_icnn", "chol_stiffness_icnn", "chol_stiffness_signed_icnn"]
]

# # good architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     "chol_energy_baseline",
#     "diag_energy_icnn",
#     "chol_energy_icnn",
#     # add whatever you want here
# ]

# %%
results = run_architecture_sweep(
    properties=TubeN7Properties(),
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)
# Out:
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tube/diag_energy_baseline__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.858e-03 | Valid: 2.608e-03
# Epoch 100 | Train: 7.400e-04 | Valid: 5.937e-04
# Epoch 200 | Train: 7.393e-04 | Valid: 5.941e-04
# Epoch 300 | Train: 7.387e-04 | Valid: 5.956e-04
# Epoch 400 | Train: 7.383e-04 | Valid: 5.964e-04
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/architecture_plots.py:234: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# ==========================================================================================
# Running architecture: diag_energy_mlp
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tube/diag_energy_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.858e-03 | Valid: 2.608e-03
# Epoch 100 | Train: 5.288e-04 | Valid: 6.557e-04
# Epoch 200 | Train: 1.764e-03 | Valid: 1.557e-03
# Epoch 300 | Train: 7.487e-04 | Valid: 1.083e-03
# Epoch 400 | Train: 9.511e-04 | Valid: 7.911e-04
# ==========================================================================================
# Running architecture: diag_energy_icnn
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tube/diag_energy_icnn__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.703e-03 | Valid: 1.090e-03
# Epoch 100 | Train: 5.367e-04 | Valid: 6.169e-04
# Epoch 200 | Train: 5.010e-04 | Valid: 5.538e-04
# Epoch 300 | Train: 4.819e-04 | Valid: 5.217e-04
# Epoch 400 | Train: 4.730e-04 | Valid: 5.069e-04
# ==========================================================================================
# Running architecture: icnn_energy
#   model_cls               : ScalarEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tube/icnn_energy__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.798e+05 | Valid: 2.400e+00
# Epoch 100 | Train: nan | Valid: nan
# Epoch 200 | Train: nan | Valid: nan
# Epoch 300 | Train: nan | Valid: nan
# Epoch 400 | Train: nan | Valid: nan
# ==========================================================================================
# Running architecture: chol_energy_baseline
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tube/chol_energy_baseline__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.858e-03 | Valid: 2.505e-03
# Epoch 100 | Train: 7.834e-04 | Valid: 5.632e-04
# Epoch 200 | Train: 7.250e-04 | Valid: 5.768e-04
# Epoch 300 | Train: 7.205e-04 | Valid: 5.669e-04
# Epoch 400 | Train: 7.190e-04 | Valid: 5.632e-04
# ==========================================================================================
# Running architecture: chol_energy_mlp
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tube/chol_energy_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.858e-03 | Valid: 2.505e-03
# Epoch 100 | Train: 4.057e-04 | Valid: 6.011e-04
# Epoch 200 | Train: 3.827e-04 | Valid: 5.802e-04
# Epoch 300 | Train: 5.317e-04 | Valid: 5.673e-04
# Epoch 400 | Train: 4.143e-04 | Valid: 4.052e-04
# ==========================================================================================
# Running architecture: chol_energy_icnn
#   model_cls               : CholeskyPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tube/chol_energy_icnn__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 2.703e-03 | Valid: 1.036e-03
# Epoch 100 | Train: 1.794e-02 | Valid: 1.451e-02
# Epoch 200 | Train: 2.242e-03 | Valid: 2.710e-03
# Epoch 300 | Train: 1.766e-03 | Valid: 2.079e-03
# Epoch 400 | Train: 1.527e-03 | Valid: 1.767e-03
# ==========================================================================================
# Running architecture: diag_stiffness_mlp
#   model_cls               : DiagonalPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tube/diag_stiffness_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 9.851e-03 | Valid: 2.541e-02
# Epoch 100 | Train: 1.260e-02 | Valid: 1.657e-02
# Epoch 200 | Train: nan | Valid: nan
# Epoch 300 | Train: nan | Valid: nan
# Epoch 400 | Train: nan | Valid: nan
# ==========================================================================================
# Running architecture: chol_stiffness_mlp
#   model_cls               : CholeskyPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tube/chol_stiffness_mlp__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 7.789e-03 | Valid: 8.649e-03
# Epoch 100 | Train: 2.049e-02 | Valid: 1.704e-02
# Epoch 200 | Train: 6.681e-03 | Valid: 6.390e-03
# Epoch 300 | Train: 3.779e-03 | Valid: 3.761e-03
# Epoch 400 | Train: 3.124e-03 | Valid: 3.074e-03

# %%
from architecture_plots import plot_architecture_comparison_paper

dir = "arch_sweep_outputs_run1_n7_tube"
# good architectures
plot_architectures = [
    "diag_energy_icnn",
    "chol_energy_icnn",
    "diag_energy_baseline",
    "chol_energy_baseline",
    # "diag_stiffness_mlp",
    # "chol_stiffness_mlp",
    # "diag_energy_mlp",
    # "chol_energy_mlp",
    # add whatever you want here
]
plot_architecture_comparison_paper(
    architectures=plot_architectures,
    # architectures=subset_all(),
    results_dir=dir,
    traj_idx=0,
)
# Out:
# {'training_loss': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/training_loss_comparison.pdf',
#  'validation_loss': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/validation_loss_comparison.pdf',
#  'training_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/training_trajectory_comparison.pdf',
#  'validation_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/validation_trajectory_comparison.pdf',
#  'training_xz_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/training_xz_trajectory_comparison.pdf',
#  'validation_xz_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/validation_xz_trajectory_comparison.pdf',
#  'combined_xz_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/combined_xz_trajectory_comparison.pdf',
#  'colors': {'diag_energy_icnn': (np.float64(0.12156862745098039),
#    np.float64(0.4666666666666667),
#    np.float64(0.7058823529411765),
#    np.float64(1.0)),
#   'chol_energy_icnn': (np.float64(1.0),
#    np.float64(0.4980392156862745),
#    np.float64(0.054901960784313725),
#    np.float64(1.0)),
#   'diag_energy_baseline': (np.float64(0.17254901960784313),
#    np.float64(0.6274509803921569),
#    np.float64(0.17254901960784313),
#    np.float64(1.0)),
#   'chol_energy_baseline': (np.float64(0.8392156862745098),
#    np.float64(0.15294117647058825),
#    np.float64(0.1568627450980392),
#    np.float64(1.0))}}

# %%
# from architecture_plots import plot_saved_results

# results_path = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/results.npz"
# plot_output_dir = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/replotted"


# plot_saved_results(
#     results_path=results_path,
#     output_dir=plot_output_dir, # if output_dir = None, image will just be shown and not saved
#     show=True,
#     make_component_plots=True,
# )

# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from animate import animate

jax.config.update("jax_enable_x64", True)

# %%
from Energy_NN_architectures import *

K_init = jnp.array([0.2, 0.0, 0.1])

# train_file = "../experiment_data/tape_data/11_noded/n11_traj1_tape_dataset_interp_11.npz"
train_file = "../experiment_data/tape_data/11_noded/n11_tape_train_dataset_new.npz"
valid_file = "../experiment_data/tape_data/11_noded/n11_tape_test_dataset_new.npz"

# %%
from properties import TapeN11Properties

properties = TapeN11Properties(mass=-0.005)
print(properties)
# Out:
# TapeN11Properties(length=None, r0=0.005, axs=None, jxs=None, ixs1=None, ixs2=None, density=600.0, E=1000000.0, N=11, start=Array([0., 0., 0.], dtype=float64), end=Array([1.05660479, 0.        , 0.04239192], dtype=float64), mass=-0.005)

# %%
params = ModelParams(
    der_K=K_init,
    key=jax.random.PRNGKey(42),
    hidden=(10,),
    which_case="ICNN",
    corr_factor=0.01,
    input_mode="raw",
    zero_reference=True,
    activation="tanh",
    mode = "anisotropic"
)

model_cls = StructuredBrazierCholeskyEnergyNN

# final_model, train_history, valid_history = train_model(properties=properties, model_cls=model_cls, params=params, train_file=train_file, valid_file=valid_file, n_epochs=500, lr=1e-2)

# %%
final_model, train_history, valid_history = train_model(
    properties=properties,
    model_cls=model_cls,
    params=params,
    train_file=train_file,
    valid_file=valid_file,
    n_epochs=1000,
    lr=5e-2,
    max_dlambda=5e-2,
    iters=10,
    ls_steps=10,
    abs_tol=5e-4,
    rel_tol=1e-4,
    fail_on_nonconvergence=True,
    hessian_reg_strength=1e-6,
    valid_every=10,
    ## early stopping and overfitting control
    weight_decay=1e-5,
    early_stopping_patience=200,
    early_stopping_min_delta=1e-5,
    restore_best_model=True,
)
# Out:
# /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/util.py:665: RuntimeWarning: Mass is non-positive; if this is because gravity is in +z, ignore, but if this is not the intention please correct.
#   base, aux = get_slinky(properties)
# Epoch 000 | Train total: 8.180e-02 | Train disp: 1.039e-02 | Train force: 0.000e+00 | Valid total: 1.187e-02 | Valid disp: 1.187e-02 | Valid force: 0.000e+00
# Epoch 100 | Train total: 5.138e-02 | Train disp: 9.971e-03 | Train force: 0.000e+00 | Valid total: 1.303e-02 | Valid disp: 1.303e-02 | Valid force: 0.000e+00
# Epoch 200 | Train total: 3.301e-02 | Train disp: 8.558e-03 | Train force: 0.000e+00 | Valid total: 1.166e-02 | Valid disp: 1.166e-02 | Valid force: 0.000e+00
# Epoch 300 | Train total: 2.964e-02 | Train disp: 6.426e-03 | Train force: 0.000e+00 | Valid total: 7.570e-03 | Valid disp: 7.570e-03 | Valid force: 0.000e+00
# Epoch 400 | Train total: 3.059e-02 | Train disp: 5.885e-03 | Train force: 0.000e+00 | Valid total: 6.283e-03 | Valid disp: 6.283e-03 | Valid force: 0.000e+00
# Epoch 500 | Train total: 1.971e-02 | Train disp: 5.574e-03 | Train force: 0.000e+00 | Valid total: 5.242e-03 | Valid disp: 5.242e-03 | Valid force: 0.000e+00
# Epoch 600 | Train total: 1.772e-02 | Train disp: 5.264e-03 | Train force: 0.000e+00 | Valid total: 4.949e-03 | Valid disp: 4.949e-03 | Valid force: 0.000e+00
# Epoch 700 | Train total: 1.786e-02 | Train disp: 5.121e-03 | Train force: 0.000e+00 | Valid total: 4.627e-03 | Valid disp: 4.627e-03 | Valid force: 0.000e+00
# Epoch 800 | Train total: 1.987e-02 | Train disp: 5.004e-03 | Train force: 0.000e+00 | Valid total: 5.684e-03 | Valid disp: 5.684e-03 | Valid force: 0.000e+00
# Epoch 900 | Train total: 1.782e-02 | Train disp: 4.951e-03 | Train force: 0.000e+00 | Valid total: 4.673e-03 | Valid disp: 4.673e-03 | Valid force: 0.000e+00
# Early stopping at epoch 910 | Best epoch: 710 | Best valid: 4.540e-03

# %%
import matplotlib.pyplot as plt
train_np = np.asarray(train_history, dtype=float).reshape(-1)
valid_np = np.asarray(valid_history, dtype=float).reshape(-1)

print(len(train_history))

idx_valid = np.where(valid_np != -1)[0]

plt.plot(np.arange(train_np.size), train_np, label="Train Loss")
plt.plot(idx_valid, valid_np[idx_valid], label="Valid Loss")
plt.yscale("log")
plt.legend()
plt.show()
# Out:
# 911

# %%
base, aux = get_slinky(properties)
valid = Dataset.load(valid_file)
train = Dataset.load(train_file)

pred = predict(final_model, base, aux, valid.idx_b, valid.xb, valid.lambdas)
pred_train = predict(final_model, base, aux, train.idx_b, train.xb, train.lambdas)
# Out:
# /var/folders/z0/3frv2l990hb5ryd49z8vm4w80000gn/T/ipykernel_35804/1889145442.py:1: RuntimeWarning: Mass is non-positive; if this is because gravity is in +z, ignore, but if this is not the intention please correct.
#   base, aux = get_slinky(properties)

# %%
animate(pred_train[0])

# %%
animate(train.qs[0])

# %%
animate(pred[0])

# %%
animate(valid.qs[0])

# %%
animate(valid.qs[1])

# %%
animate(pred[1])

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import jax.numpy as jnp

n_cases = pred.shape[0]
colors = cm.viridis(jnp.linspace(0, 1, n_cases))
center_node = properties.N // 2

fig, ax = plt.subplots(figsize=(8, 5))

for i in range(n_cases):
    c = colors[i]

    # X
    ax.plot(pred[i, :, 4*center_node + 0], color=c, linestyle='-')
    ax.plot(valid.qs[i, :, 4*center_node + 0], color=c, linestyle='--')

    # Z
    ax.plot(pred[i, :, 4*center_node + 2], color=c, linestyle='-', alpha=0.6)
    ax.plot(valid.qs[i, :, 4*center_node + 2], color=c, linestyle='--', alpha=0.6)

pred_line = mlines.Line2D([], [], color='black', linestyle='-', label='Prediction')
truth_line = mlines.Line2D([], [], color='black', linestyle='--', label='Truth')
ax.legend(handles=[pred_line, truth_line])

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=0, vmax=n_cases - 1))
sm.set_array([])  # helps matplotlib know this is a valid mappable
fig.colorbar(sm, ax=ax, label='Case index i')

ax.set_title("Prediction vs Truth on Unseen BC")
ax.set_xlabel("lambda_idx")
ax.set_ylabel("Position (m)")
fig.tight_layout()
plt.show()

# %%
print(final_model.get_K0())
# Out:
# [1.68308673e-03 5.73404435e-09 1.57714443e-02]

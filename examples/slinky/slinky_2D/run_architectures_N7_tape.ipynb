# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from properties import *

# %%
train_file = "../experiment_data/n7_tape_train_dataset.npz"
valid_file = "../experiment_data/n7_tape_test_dataset.npz"

# %%
from run_architectures import *
dir = "arch_sweep_outputs_run1_n7_tape"

cfg = SweepConfig(
    der_K_diag=(2.0, 0.2),
    der_K_chol=(2.0, 0.0, 0.2),
    hidden=(10,10),
    corr_factor=0.01,
    input_mode="raw",
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=1e-2,
    seed=42,
    output_dir=dir,
    iters = 10,
    max_dlambda = 5e-2
)


# # Example: choose only selected architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     # "chol_stiffness_mlp",
#     # add whatever you want here
# ]
selected_architectures = subset_all()  # run all architectures

# remove mlp_energy, chol_stiffness_signed_mlp, all stiffness_icnn from the plot since they are so bad that they throw off the scale and make it hard to see differences between the other architectures
selected_architectures = [
    arch for arch in subset_all()
    if arch not in ["mlp_energy", "chol_stiffness_signed_mlp", "diag_stiffness_icnn", "chol_stiffness_icnn", "chol_stiffness_signed_icnn"]
]

# # good architectures
# selected_architectures = [
#     "diag_energy_baseline",
#     "chol_energy_baseline",
#     "diag_energy_icnn",
#     "chol_energy_icnn",
#     # add whatever you want here
# ]

# %%
results = run_architecture_sweep(
    properties=TapeN7Properties(),
    train_file=train_file,
    valid_file=valid_file,
    cfg=cfg,
    selected_architectures=selected_architectures,
)
# Out:
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : raw
#   activation              : tanh
#   corr_factor             : 0.01
#   zero_reference          : True
#   seed                    : 42
#   max_dlambda             : 0.05
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 1e-08
#   rel_tol                 : 1e-06
#   fail_on_nonconvergence  : False
#   exp_dir                 : arch_sweep_outputs_run1_n7_tape/diag_energy_baseline__hid_10x10__inp_raw__act_tanh__corr_0.01__zr1__seed_42__mdl_0.05__it_10
#   energy snapshots        : initial=True, final=True, epochs=(), every=None
#   energy snapshot split   : valid
# ==========================================================================================
# Epoch 000 | Train: 1.245e-01 | Valid: 5.923e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results = run_architecture_sweep(
#       2     properties=TapeN7Properties(),
#       3     train_file=train_file,
#       4     valid_file=valid_file,
#       5     cfg=cfg,
#       6     selected_architectures=selected_architectures,
#       7 )
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/run_architectures.py:705, in run_architecture_sweep(properties, train_file, valid_file, cfg, selected_architectures)
#     703 spec = registry[arch_name]
#     704 try:
# --> 705     results[arch_name] = run_one_architecture(
#     706         properties=properties,
#     707         train_file=train_file,
#     708         valid_file=valid_file,
#     709         spec=spec,
#     710         cfg=cfg,
#     711     )
#     712 except Exception as e:
#     713     # extra guard, though run_one_architecture already catches failures
#     714     failure_reason = _classify_exception_message(repr(e))
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/run_architectures.py:476, in run_one_architecture(properties, train_file, valid_file, spec, cfg)
#     465     (
#     466         baseline_callback,
#     467         baseline_history_epochs,
#     468         baseline_history_values,
#     469         baseline_history_labels,
#     470     ) = _make_baseline_history_callback(spec.model_cls)
#     472 try:
#     473     # -------------------------
#     474     # Train
#     475     # -------------------------
# --> 476     model, train_hist, valid_hist = train_model(
#     477         properties=properties,
#     478         model_cls=spec.model_cls,
#     479         params=params,
#     480         train_file=train_file,
#     481         valid_file=valid_file,
#     482         n_epochs=cfg.n_epochs,
#     483         lr=cfg.lr,
#     484         snapshot_fn=snapshot_fn,
#     485         snapshot_every=cfg.energy_snapshot_every,
#     486         snapshot_epochs=snapshot_epochs,
#     487         snapshot_before_training=snapshot_before_training,
#     488         epoch_callback=baseline_callback,
#     489         valid_every=cfg.valid_every,
#     490         max_dlambda=cfg.max_dlambda,
#     491         iters=cfg.iters,
#     492         ls_steps=cfg.ls_steps,
#     493         abs_tol=cfg.abs_tol,
#     494         rel_tol=cfg.rel_tol,
#     495         fail_on_nonconvergence=cfg.fail_on_nonconvergence,
#     496     )
#     498     # -------------------------
#     499     # Predict
#     500     # -------------------------
#     501     base, aux = get_slinky(properties)
#
# File ~/GitRepos/dismech-jax/examples/slinky/slinky_2D/util.py:317, in train_model(properties, model_cls, params, train_file, valid_file, n_epochs, lr, snapshot_fn, snapshot_every, snapshot_epochs, snapshot_before_training, epoch_callback, valid_every, max_dlambda, iters, ls_steps, abs_tol, rel_tol, fail_on_nonconvergence)
#     309     epoch_callback(
#     310         model=model,
#     311         epoch=-1,
#     312         train_loss=jnp.nan,
#     313         val_loss=jnp.nan,
#     314     )
#     316 for i in range(n_epochs):
# --> 317     model, opt_state, train_loss = step(model, opt_state)
#     318     train_hist.append(train_loss)
#     320     do_valid = (valid_every is not None) and (
#     321         (i % valid_every == 0) or (i == n_epochs - 1)
#     322     )
#
#     [... skipping hidden 1 frame]
#
# File ~/GitRepos/dismech-jax/.venv/lib/python3.13/site-packages/equinox/_jit.py:271, in _call(jit_wrapper, is_lower, args, kwargs)
#     266     # We need to include the explicit `isinstance(marker, jax.Array)` check due
#     267     # to https://github.com/patrick-kidger/equinox/issues/988
#     268     if not isinstance(marker, jax.core.Tracer) and isinstance(
#     269         marker, jax.Array
#     270     ):
# --> 271         marker.block_until_ready()
#     272 except (JaxRuntimeError, ValueError) as e:
#     273     # Catch Equinox's runtime errors, and re-raise them with actually useful
#     274     # information. (By default XlaRuntimeError produces a lot of terrifying
#     275     # but useless information.)
#     276     if last_error_info is not None and "_EquinoxRuntimeError: " in str(e):
#
# KeyboardInterrupt:

# %%
from architecture_plots import plot_architecture_comparison_paper

dir = "arch_sweep_outputs_run1_n7_tape"
# good architectures
plot_architectures = [
    "diag_energy_icnn",
    "chol_energy_icnn",
    "diag_energy_baseline",
    "chol_energy_baseline",
    # "diag_stiffness_mlp",
    # "chol_stiffness_mlp",
    # "diag_energy_mlp",
    # "chol_energy_mlp",
    # add whatever you want here
]
plot_architecture_comparison_paper(
    architectures=plot_architectures,
    # architectures=subset_all(),
    results_dir=dir,
    traj_idx=0,
)
# Out:
# {'training_loss': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/training_loss_comparison.pdf',
#  'validation_loss': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/validation_loss_comparison.pdf',
#  'training_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/training_trajectory_comparison.pdf',
#  'validation_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/validation_trajectory_comparison.pdf',
#  'training_xz_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/training_xz_trajectory_comparison.pdf',
#  'validation_xz_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/validation_xz_trajectory_comparison.pdf',
#  'combined_xz_trajectory': 'arch_sweep_outputs_run1_n7_tube/paper_ready_architecture_comparison/combined_xz_trajectory_comparison.pdf',
#  'colors': {'diag_energy_icnn': (np.float64(0.12156862745098039),
#    np.float64(0.4666666666666667),
#    np.float64(0.7058823529411765),
#    np.float64(1.0)),
#   'chol_energy_icnn': (np.float64(1.0),
#    np.float64(0.4980392156862745),
#    np.float64(0.054901960784313725),
#    np.float64(1.0)),
#   'diag_energy_baseline': (np.float64(0.17254901960784313),
#    np.float64(0.6274509803921569),
#    np.float64(0.17254901960784313),
#    np.float64(1.0)),
#   'chol_energy_baseline': (np.float64(0.8392156862745098),
#    np.float64(0.15294117647058825),
#    np.float64(0.1568627450980392),
#    np.float64(1.0))}}

# %%
# from architecture_plots import plot_saved_results

# results_path = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/results.npz"
# plot_output_dir = "arch_sweep_outputs_all12_n9strip_testing/diag_energy_baseline__hid_10__inp_raw__act_tanh__corr_1__zr1__seed_0__mdl_0.01__it_5/replotted"


# plot_saved_results(
#     results_path=results_path,
#     output_dir=plot_output_dir, # if output_dir = None, image will just be shown and not saved
#     show=True,
#     make_component_plots=True,
# )

# %%
import numpy as np
from experiment_data.combine_multiple_datasets import combine_multiple_datasets_with_forces

# %%
slinky_3_noded_simulation_location = "simulation_data_2D/3_noded/"

# training data
combine_multiple_datasets_with_forces(
    [
        f"{slinky_3_noded_simulation_location}n3_traj1_pull_out.npz",
        f"{slinky_3_noded_simulation_location}n3_traj3_diag_down.npz",
        # f"{slinky_3_noded_simulation_location}n3_traj6_vertical_up.npz",
        # f"{slinky_3_noded_simulation_location}n3_traj7_vertical_down.npz",
    ],
    f"{slinky_3_noded_simulation_location}n3_slinky_sim_train_dataset.npz",
)

# test data
combine_multiple_datasets_with_forces(
    [
        f"{slinky_3_noded_simulation_location}n3_traj2_diag_up.npz",
        # f"{slinky_3_noded_simulation_location}n3_traj3_diag_down.npz",
        f"{slinky_3_noded_simulation_location}n3_traj4_diag2_up.npz",
        f"{slinky_3_noded_simulation_location}n3_traj5_diag2_down.npz",
        f"{slinky_3_noded_simulation_location}n3_traj6_vertical_up.npz",
        f"{slinky_3_noded_simulation_location}n3_traj7_vertical_down.npz",
        f"{slinky_3_noded_simulation_location}n3_traj8_diagonal_up.npz",
        f"{slinky_3_noded_simulation_location}n3_traj9_diagonal_down.npz",
    ],
    f"{slinky_3_noded_simulation_location}n3_slinky_sim_test_dataset.npz",
)
# Out:
# Processed simulation_data_2D/3_noded/n3_traj1_pull_out.npz
#   qs       (1, 150, 11)
#   xb       (1, 150, 8)
#   F        (1, 150, 3)
#   lambdas  (1, 150)
#   valid    (1, 150)
#   idx_b    (1, 8)
#
# Processed simulation_data_2D/3_noded/n3_traj3_diag_down.npz
#   qs       (1, 150, 11)
#   xb       (1, 150, 8)
#   F        (1, 150, 3)
#   lambdas  (1, 150)
#   valid    (1, 150)
#   idx_b    (1, 8)
#
# FINAL
#   qs       (2, 150, 11)
#   xb       (2, 150, 8)
#   F        (2, 150, 3)
#   lambdas  (2, 150)
#   valid    (2, 150)
#   idx_b    (8,)
#
# Combined 2 files into simulation_data_2D/3_noded/n3_slinky_sim_train_dataset.npz.
#
# Processed simulation_data_2D/3_noded/n3_traj2_diag_up.npz
#   qs       (1, 150, 11)
#   xb       (1, 150, 8)
#   F        (1, 150, 3)
#   lambdas  (1, 150)
#   valid    (1, 150)
#   idx_b    (1, 8)
#
# Processed simulation_data_2D/3_noded/n3_traj4_diag2_up.npz
#   qs       (1, 150, 11)
#   xb       (1, 150, 8)
#   F        (1, 150, 3)
# ...

# %%
slinky_3_noded_simulation_location = "simulation_data_2D/5_noded/"

# training data
combine_multiple_datasets_with_forces(
    [
        f"{slinky_3_noded_simulation_location}n3_traj1_pull_out_5_noded.npz",
        f"{slinky_3_noded_simulation_location}n3_traj3_diag_down_5_noded.npz",
        # f"{slinky_3_noded_simulation_location}n3_traj7_vertical_down_5_noded.npz",
    ],
    f"{slinky_3_noded_simulation_location}n5_slinky_sim_train_dataset.npz",
)

# test data
combine_multiple_datasets_with_forces(
    [
        f"{slinky_3_noded_simulation_location}n3_traj2_diag_up_5_noded.npz",
        # f"{slinky_3_noded_simulation_location}n3_traj3_diag_down_5_noded.npz",
        f"{slinky_3_noded_simulation_location}n3_traj4_diag2_up_5_noded.npz",
        f"{slinky_3_noded_simulation_location}n3_traj5_diag2_down_5_noded.npz",
        f"{slinky_3_noded_simulation_location}n3_traj6_vertical_up_5_noded.npz",
    ],
    f"{slinky_3_noded_simulation_location}n5_slinky_sim_test_dataset.npz",
)
# Out:
# Processed simulation_data_2D/5_noded/n3_traj1_pull_out_5_noded.npz
#   qs       (1, 150, 19)
#   xb       (1, 150, 8)
#   F        (1, 150, 3)
#   lambdas  (1, 150)
#   valid    (1, 150)
#   idx_b    (1, 8)
#
# Processed simulation_data_2D/5_noded/n3_traj3_diag_down_5_noded.npz
#   qs       (1, 150, 19)
#   xb       (1, 150, 8)
#   F        (1, 150, 3)
#   lambdas  (1, 150)
#   valid    (1, 150)
#   idx_b    (1, 8)
#
# FINAL
#   qs       (2, 150, 19)
#   xb       (2, 150, 8)
#   F        (2, 150, 3)
#   lambdas  (2, 150)
#   valid    (2, 150)
#   idx_b    (8,)
#
# Combined 2 files into simulation_data_2D/5_noded/n5_slinky_sim_train_dataset.npz.
#
# Processed simulation_data_2D/5_noded/n3_traj2_diag_up_5_noded.npz
#   qs       (1, 150, 19)
#   xb       (1, 150, 8)
#   F        (1, 150, 3)
#   lambdas  (1, 150)
#   valid    (1, 150)
#   idx_b    (1, 8)
#
# Processed simulation_data_2D/5_noded/n3_traj4_diag2_up_5_noded.npz
#   qs       (1, 150, 19)
#   xb       (1, 150, 8)
# ...

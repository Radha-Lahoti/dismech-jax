# %% [markdown]
# # N3 Slinky Hessian Regularization vs Max `dλ`
#
# This notebook runs the regularization ablation for the 3-node simulated slinky using the base training settings from `run_architectures_N3_slinky_sim_all.ipynb`. It trains models across Hessian regularizer strengths, evaluates the largest stable inference continuation step, computes Hessian diagnostics, and saves paper-ready summary plots.

# %%
import json
import os
from pathlib import Path

import jax
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

jax.config.update("jax_enable_x64", True)
os.environ.setdefault("XLA_PYTHON_CLIENT_PREALLOCATE", "false")

from properties import SlinkyN3Properties
from run_architectures import SweepConfig, subset_all
from run_hessian_reg_max_dlambda_experiment import build_arg_parser, run_experiment

ROOT = Path.cwd()
OUTPUT_DIR = ROOT / "hessian_reg_max_dlambda_outputs_n3_slinky_sim"
FIGURE_DIR = OUTPUT_DIR / "paper_figures"
FIGURE_DIR.mkdir(parents=True, exist_ok=True)

# Copied from run_architectures_N3_slinky_sim_all.ipynb
train_file = "../simulation_data_2D/3_noded/n3_slinky_sim_train_dataset_7_trajs.npz"
valid_file = "../simulation_data_2D/3_noded/n3_slinky_sim_test_dataset_6_trajs.npz"
properties = SlinkyN3Properties()
K_init_chol = (0.02, 0.0, 0.05)
K_init_diag = (0.02, 0.05)

base_cfg = SweepConfig(
    der_K_diag=K_init_diag,
    der_K_chol=K_init_chol,
    hidden=(10, 10),
    corr_factor=0.05,
    input_mode="invariant",
    only_stretching_NN=True,
    only_bending_NN=False,
    zero_reference=True,
    activation="tanh",
    n_epochs=500,
    lr=5e-3,
    seed=42,
    valid_every=1,
    max_dlambda=1e-2,
    iters=10,
    ls_steps=10,
    abs_tol=1e-4,
    rel_tol=1e-4,
    early_stop=True,
    train_fail_on_nonconvergence=False,
    prediction_fail_on_nonconvergence=False,
    hessian_reg_strength=1e-4,
    hessian_reg_probes=1,
    hessian_reg_seed=0,
    force_key="F",
    force_loss_strength=0.1,
    force_components=(0,),
    force_sign=1.0,
    return_loss_components=True,
    early_stopping=True,
    early_stopping_patience=200,
    early_stopping_min_delta=1e-5,
    early_stopping_warmup_epochs=200,
    restore_best_model=True,
    output_dir=str(OUTPUT_DIR),
    save_npz=True,
    save_model=True,
    save_plots=True,
    save_force_predictions=True,
    plot_force_predictions=True,
    save_hessian_diagnostics=False,
    save_energy_landscapes=False,
    verbose=True,
    continue_on_failure=True,
)

print(f"Output dir: {OUTPUT_DIR.resolve()}")
# Out:
# Output dir: /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim

# %% [markdown]
# ## Ablation Grid
#
# `TRAIN_MAX_DLAMBDA_FOR_ABLATION` is intentionally conservative to isolate post-training solver robustness. Set it to `base_cfg.max_dlambda` if you want to train under the exact previous continuation step.

# %%
RUN_EXPERIMENT = True

SELECTED_ARCHITECTURES = tuple(
    arch for arch in subset_all()
    if arch not in ["mlp_energy", "chol_stiffness_signed_mlp", "diag_stiffness_icnn", "chol_stiffness_icnn", "chol_stiffness_signed_icnn"]
)

# For the full architecture set instead, uncomment:
# SELECTED_ARCHITECTURES = tuple(subset_all())

SEEDS = (0,1,2)
HESSIAN_REG_STRENGTHS = (0.0, 1e-8, 1e-6, 1e-4)
EVAL_MAX_DLAMBDA_VALUES = (1e-3, 1e-2, 1e-1, 1.0)
TRAIN_MAX_DLAMBDA_FOR_ABLATION = 1e-2

print("Architectures:", SELECTED_ARCHITECTURES)
print("Seeds:", SEEDS)
print("Hessian regularizers:", HESSIAN_REG_STRENGTHS)
print("Eval max_dlambda values:", EVAL_MAX_DLAMBDA_VALUES)
print("Train max_dlambda:", TRAIN_MAX_DLAMBDA_FOR_ABLATION)
# Out:
# Architectures: ('diag_energy_baseline', 'diag_energy_mlp', 'diag_energy_icnn', 'icnn_energy', 'chol_energy_baseline', 'chol_energy_mlp', 'chol_energy_icnn', 'diag_stiffness_mlp', 'chol_stiffness_mlp')
# Seeds: (0, 1, 2)
# Hessian regularizers: (0.0, 1e-08, 1e-06, 0.0001)
# Eval max_dlambda values: (0.001, 0.01, 0.1, 1.0)
# Train max_dlambda: 0.01

# %%
def csv(values):
    return ",".join(str(v) for v in values)

argv = [
    "--properties-class", "SlinkyN3Properties",
    "--train-file", train_file,
    "--valid-file", valid_file,
    "--architectures", csv(SELECTED_ARCHITECTURES),
    "--seeds", csv(SEEDS),
    "--hessian-reg-strengths", csv(HESSIAN_REG_STRENGTHS),
    "--eval-max-dlambda-values", csv(EVAL_MAX_DLAMBDA_VALUES),
    "--train-max-dlambda", str(TRAIN_MAX_DLAMBDA_FOR_ABLATION),
    "--output-dir", str(OUTPUT_DIR),
    "--der-k-diag", csv(base_cfg.der_K_diag),
    "--der-k-chol", csv(base_cfg.der_K_chol),
    "--hidden", csv(base_cfg.hidden),
    "--corr-factor", str(base_cfg.corr_factor),
    "--input-mode", base_cfg.input_mode,
    "--activation", base_cfg.activation,
    "--n-epochs", str(base_cfg.n_epochs),
    "--lr", str(base_cfg.lr),
    "--valid-every", str(base_cfg.valid_every),
    "--iters", str(base_cfg.iters),
    "--ls-steps", str(base_cfg.ls_steps),
    "--abs-tol", str(base_cfg.abs_tol),
    "--rel-tol", str(base_cfg.rel_tol),
    "--hessian-reg-probes", str(base_cfg.hessian_reg_probes),
    "--hessian-reg-seed", str(base_cfg.hessian_reg_seed),
    "--hessian-max-trajectories", "1",
    "--hessian-stride", "10",
    "--force-key", base_cfg.force_key,
    "--force-loss-strength", str(base_cfg.force_loss_strength),
    "--force-components", csv(base_cfg.force_components),
    "--force-sign", str(base_cfg.force_sign),
    "--early-stopping-patience", str(base_cfg.early_stopping_patience),
    "--early-stopping-min-delta", str(base_cfg.early_stopping_min_delta),
    "--early-stopping-warmup-epochs", str(base_cfg.early_stopping_warmup_epochs),
    "--no-plots",
]
if base_cfg.only_stretching_NN:
    argv.append("--only-stretching-nn")
if base_cfg.only_bending_NN:
    argv.append("--only-bending-nn")
if not base_cfg.zero_reference:
    argv.append("--no-zero-reference")
if not base_cfg.early_stop:
    argv.append("--no-early-stop")
if not base_cfg.train_fail_on_nonconvergence:
    argv.append("--train-allow-nonconvergence")
if base_cfg.return_loss_components:
    argv.append("--return-loss-components")
if not base_cfg.early_stopping:
    argv.append("--no-early-stopping")
if not base_cfg.restore_best_model:
    argv.append("--no-restore-best-model")

args = build_arg_parser().parse_args(argv)
if RUN_EXPERIMENT:
    records = run_experiment(args)
else:
    print("RUN_EXPERIMENT=False; skipping training/evaluation.")
# Out:
# [train] arch=diag_energy_baseline seed=0 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 0
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_energy_baseline__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_0__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 1.277e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.048e-01 | Valid disp: 2.684e-02 | Valid force: 7.792e-01
# Epoch 100 | Train total: 7.101e-02 | Train disp: 1.374e-02 | Train force: 5.728e-01 | Valid total: 5.558e-02 | Valid disp: 1.105e-02 | Valid force: 4.454e-01
# Epoch 200 | Train total: 4.404e-02 | Train disp: 8.351e-03 | Train force: 3.569e-01 | Valid total: 2.966e-02 | Valid disp: 6.262e-03 | Valid force: 2.340e-01
# Epoch 300 | Train total: 3.791e-02 | Train disp: 6.987e-03 | Train force: 3.092e-01 | Valid total: 2.217e-02 | Valid disp: 5.009e-03 | Valid force: 1.717e-01
# Epoch 400 | Train total: 3.704e-02 | Train disp: 6.664e-03 | Train force: 3.037e-01 | Valid total: 2.059e-02 | Valid disp: 4.710e-03 | Valid force: 1.588e-01
# [eval] arch=diag_energy_baseline seed=0 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=diag_energy_baseline seed=0 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=diag_energy_baseline seed=0 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_energy_baseline seed=0 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_baseline seed=0 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_baseline seed=0 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=diag_energy_baseline seed=1 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 1
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_energy_baseline__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_1__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 1.277e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.048e-01 | Valid disp: 2.684e-02 | Valid force: 7.792e-01
# Epoch 100 | Train total: 7.101e-02 | Train disp: 1.374e-02 | Train force: 5.728e-01 | Valid total: 5.558e-02 | Valid disp: 1.105e-02 | Valid force: 4.454e-01
# Epoch 200 | Train total: 4.404e-02 | Train disp: 8.351e-03 | Train force: 3.569e-01 | Valid total: 2.966e-02 | Valid disp: 6.262e-03 | Valid force: 2.340e-01
# Epoch 300 | Train total: 3.791e-02 | Train disp: 6.987e-03 | Train force: 3.092e-01 | Valid total: 2.217e-02 | Valid disp: 5.009e-03 | Valid force: 1.717e-01
# Epoch 400 | Train total: 3.704e-02 | Train disp: 6.664e-03 | Train force: 3.037e-01 | Valid total: 2.059e-02 | Valid disp: 4.710e-03 | Valid force: 1.588e-01
# [eval] arch=diag_energy_baseline seed=1 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=diag_energy_baseline seed=1 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=diag_energy_baseline seed=1 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_energy_baseline seed=1 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_baseline seed=1 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_baseline seed=1 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=diag_energy_baseline seed=2 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_energy_baseline
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : baseline
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 2
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_energy_baseline__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_2__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 1.277e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.048e-01 | Valid disp: 2.684e-02 | Valid force: 7.792e-01
# Epoch 100 | Train total: 7.101e-02 | Train disp: 1.374e-02 | Train force: 5.728e-01 | Valid total: 5.558e-02 | Valid disp: 1.105e-02 | Valid force: 4.454e-01
# Epoch 200 | Train total: 4.404e-02 | Train disp: 8.351e-03 | Train force: 3.569e-01 | Valid total: 2.966e-02 | Valid disp: 6.262e-03 | Valid force: 2.340e-01
# Epoch 300 | Train total: 3.791e-02 | Train disp: 6.987e-03 | Train force: 3.092e-01 | Valid total: 2.217e-02 | Valid disp: 5.009e-03 | Valid force: 1.717e-01
# Epoch 400 | Train total: 3.704e-02 | Train disp: 6.664e-03 | Train force: 3.037e-01 | Valid total: 2.059e-02 | Valid disp: 4.710e-03 | Valid force: 1.588e-01
# [eval] arch=diag_energy_baseline seed=2 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=diag_energy_baseline seed=2 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=diag_energy_baseline seed=2 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_energy_baseline seed=2 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_baseline seed=2 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_baseline seed=2 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=diag_energy_mlp seed=0 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_energy_mlp
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 0
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_energy_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_0__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 1.277e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.048e-01 | Valid disp: 2.684e-02 | Valid force: 7.792e-01
# Epoch 100 | Train total: 5.855e-02 | Train disp: 1.216e-02 | Train force: 4.639e-01 | Valid total: 4.274e-02 | Valid disp: 1.006e-02 | Valid force: 3.269e-01
# Epoch 200 | Train total: 2.970e-02 | Train disp: 8.346e-03 | Train force: 2.136e-01 | Valid total: 2.433e-02 | Valid disp: 6.645e-03 | Valid force: 1.768e-01
# Epoch 300 | Train total: 2.283e-02 | Train disp: 7.347e-03 | Train force: 1.548e-01 | Valid total: 1.968e-02 | Valid disp: 5.620e-03 | Valid force: 1.406e-01
# Epoch 400 | Train total: 2.192e-02 | Train disp: 7.109e-03 | Train force: 1.481e-01 | Valid total: 1.783e-02 | Valid disp: 5.383e-03 | Valid force: 1.245e-01
# [eval] arch=diag_energy_mlp seed=0 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=diag_energy_mlp seed=0 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=diag_energy_mlp seed=0 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_energy_mlp seed=0 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_mlp seed=0 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_mlp seed=0 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=diag_energy_mlp seed=1 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_energy_mlp
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 1
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_energy_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_1__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 1.277e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.048e-01 | Valid disp: 2.684e-02 | Valid force: 7.792e-01
# Epoch 100 | Train total: 5.895e-02 | Train disp: 1.190e-02 | Train force: 4.704e-01 | Valid total: 4.311e-02 | Valid disp: 1.006e-02 | Valid force: 3.306e-01
# Epoch 200 | Train total: 2.929e-02 | Train disp: 8.559e-03 | Train force: 2.073e-01 | Valid total: 2.593e-02 | Valid disp: 6.699e-03 | Valid force: 1.923e-01
# Epoch 300 | Train total: 2.347e-02 | Train disp: 7.313e-03 | Train force: 1.615e-01 | Valid total: 2.064e-02 | Valid disp: 5.547e-03 | Valid force: 1.510e-01
# Epoch 400 | Train total: 2.235e-02 | Train disp: 7.041e-03 | Train force: 1.531e-01 | Valid total: 1.801e-02 | Valid disp: 5.287e-03 | Valid force: 1.273e-01
# [eval] arch=diag_energy_mlp seed=1 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=diag_energy_mlp seed=1 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=diag_energy_mlp seed=1 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_energy_mlp seed=1 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_mlp seed=1 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_mlp seed=1 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=diag_energy_mlp seed=2 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_energy_mlp
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 2
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_energy_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_2__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 1.277e-01 | Train disp: 3.253e-02 | Train force: 9.520e-01 | Valid total: 1.048e-01 | Valid disp: 2.684e-02 | Valid force: 7.792e-01
# Epoch 100 | Train total: 5.880e-02 | Train disp: 1.198e-02 | Train force: 4.682e-01 | Valid total: 4.255e-02 | Valid disp: 9.961e-03 | Valid force: 3.259e-01
# Epoch 200 | Train total: 2.892e-02 | Train disp: 8.572e-03 | Train force: 2.035e-01 | Valid total: 2.728e-02 | Valid disp: 6.733e-03 | Valid force: 2.055e-01
# Epoch 300 | Train total: 2.329e-02 | Train disp: 7.313e-03 | Train force: 1.598e-01 | Valid total: 2.085e-02 | Valid disp: 5.555e-03 | Valid force: 1.530e-01
# Epoch 400 | Train total: 2.254e-02 | Train disp: 7.063e-03 | Train force: 1.548e-01 | Valid total: 1.923e-02 | Valid disp: 5.315e-03 | Valid force: 1.392e-01
# [eval] arch=diag_energy_mlp seed=2 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=diag_energy_mlp seed=2 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=diag_energy_mlp seed=2 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_energy_mlp seed=2 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_mlp seed=2 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_mlp seed=2 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=diag_energy_icnn seed=0 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_energy_icnn
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 0
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_energy_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_0__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 1.016e-01 | Train disp: 2.407e-02 | Train force: 7.748e-01 | Valid total: 3.077e-02 | Valid disp: 8.145e-03 | Valid force: 2.262e-01
# Epoch 100 | Train total: 2.247e-02 | Train disp: 8.145e-03 | Train force: 1.432e-01 | Valid total: 1.162e-02 | Valid disp: 7.317e-03 | Valid force: 4.304e-02
# Epoch 200 | Train total: 2.162e-02 | Train disp: 7.954e-03 | Train force: 1.367e-01 | Valid total: 1.165e-02 | Valid disp: 7.139e-03 | Valid force: 4.510e-02
# Epoch 300 | Train total: 2.115e-02 | Train disp: 7.924e-03 | Train force: 1.323e-01 | Valid total: 1.158e-02 | Valid disp: 7.068e-03 | Valid force: 4.515e-02
# Epoch 400 | Train total: 2.092e-02 | Train disp: 7.910e-03 | Train force: 1.301e-01 | Valid total: 1.154e-02 | Valid disp: 7.026e-03 | Valid force: 4.517e-02
# [eval] arch=diag_energy_icnn seed=0 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=diag_energy_icnn seed=0 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=diag_energy_icnn seed=0 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_energy_icnn seed=0 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_icnn seed=0 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_energy_icnn seed=0 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=diag_energy_icnn seed=1 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_energy_icnn
#   model_cls               : DiagonalPlusEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 1
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_energy_icnn__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_1__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 1
eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=icnn_energy seed=1 hreg=1e-06 train_success=True largest_eval=None
#
# [train] arch=icnn_energy seed=1 hreg=0.0001 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: icnn_energy
#   model_cls               : ScalarEnergyNN
#   which_case              : ICNN
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 1
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
# ...
# [saturate] arch=diag_stiffness_mlp seed=0 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_stiffness_mlp seed=0 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_stiffness_mlp seed=0 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_stiffness_mlp seed=0 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=diag_stiffness_mlp seed=1 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_stiffness_mlp
#   model_cls               : DiagonalPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 1
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_stiffness_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_1__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 2.656e+01 | Train disp: 4.707e-03 | Train force: 2.656e+02 | Valid total: 1.966e+01 | Valid disp: 2.297e-03 | Valid force: 1.965e+02
# Epoch 100 | Train total: 1.509e+01 | Train disp: 4.684e-03 | Train force: 1.509e+02 | Valid total: 1.206e+01 | Valid disp: 2.289e-03 | Valid force: 1.206e+02
# Epoch 200 | Train total: 9.689e+00 | Train disp: 4.668e-03 | Train force: 9.684e+01 | Valid total: 8.241e+00 | Valid disp: 2.302e-03 | Valid force: 8.239e+01
# Epoch 300 | Train total: 6.908e+00 | Train disp: 4.657e-03 | Train force: 6.903e+01 | Valid total: 6.221e+00 | Valid disp: 2.317e-03 | Valid force: 6.219e+01
# Epoch 400 | Train total: 5.756e+00 | Train disp: 4.649e-03 | Train force: 5.752e+01 | Valid total: 5.325e+00 | Valid disp: 2.322e-03 | Valid force: 5.322e+01
# [eval] arch=diag_stiffness_mlp seed=1 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=diag_stiffness_mlp seed=1 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=diag_stiffness_mlp seed=1 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_stiffness_mlp seed=1 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_stiffness_mlp seed=1 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_stiffness_mlp seed=1 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=diag_stiffness_mlp seed=2 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: diag_stiffness_mlp
#   model_cls               : DiagonalPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 2
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/diag_stiffness_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_2__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 2.681e+01 | Train disp: 4.709e-03 | Train force: 2.680e+02 | Valid total: 1.984e+01 | Valid disp: 2.299e-03 | Valid force: 1.984e+02
# Epoch 100 | Train total: 1.534e+01 | Train disp: 4.685e-03 | Train force: 1.533e+02 | Valid total: 1.222e+01 | Valid disp: 2.291e-03 | Valid force: 1.221e+02
# Epoch 200 | Train total: 9.761e+00 | Train disp: 4.670e-03 | Train force: 9.756e+01 | Valid total: 8.280e+00 | Valid disp: 2.302e-03 | Valid force: 8.277e+01
# Epoch 300 | Train total: 6.953e+00 | Train disp: 4.659e-03 | Train force: 6.948e+01 | Valid total: 6.255e+00 | Valid disp: 2.318e-03 | Valid force: 6.253e+01
# Epoch 400 | Train total: 5.801e+00 | Train disp: 4.650e-03 | Train force: 5.796e+01 | Valid total: 5.368e+00 | Valid disp: 2.323e-03 | Valid force: 5.365e+01
# [eval] arch=diag_stiffness_mlp seed=2 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=diag_stiffness_mlp seed=2 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=diag_stiffness_mlp seed=2 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=diag_stiffness_mlp seed=2 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_stiffness_mlp seed=2 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=diag_stiffness_mlp seed=2 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=chol_stiffness_mlp seed=0 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: chol_stiffness_mlp
#   model_cls               : CholeskyPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 0
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/chol_stiffness_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_0__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 2.647e+01 | Train disp: 4.706e-03 | Train force: 2.647e+02 | Valid total: 1.959e+01 | Valid disp: 2.290e-03 | Valid force: 1.958e+02
# Epoch 100 | Train total: 1.466e+01 | Train disp: 4.467e-03 | Train force: 1.465e+02 | Valid total: 1.171e+01 | Valid disp: 2.133e-03 | Valid force: 1.170e+02
# Epoch 200 | Train total: 9.194e+00 | Train disp: 4.486e-03 | Train force: 9.190e+01 | Valid total: 7.845e+00 | Valid disp: 2.175e-03 | Valid force: 7.843e+01
# Epoch 300 | Train total: 6.485e+00 | Train disp: 4.502e-03 | Train force: 6.480e+01 | Valid total: 5.886e+00 | Valid disp: 2.200e-03 | Valid force: 5.884e+01
# Epoch 400 | Train total: 5.384e+00 | Train disp: 4.508e-03 | Train force: 5.380e+01 | Valid total: 5.026e+00 | Valid disp: 2.209e-03 | Valid force: 5.024e+01
# [eval] arch=chol_stiffness_mlp seed=0 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=chol_stiffness_mlp seed=0 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=chol_stiffness_mlp seed=0 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=chol_stiffness_mlp seed=0 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=chol_stiffness_mlp seed=0 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=chol_stiffness_mlp seed=0 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=chol_stiffness_mlp seed=1 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: chol_stiffness_mlp
#   model_cls               : CholeskyPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 1
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/chol_stiffness_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_1__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 2.656e+01 | Train disp: 4.707e-03 | Train force: 2.656e+02 | Valid total: 1.965e+01 | Valid disp: 2.291e-03 | Valid force: 1.965e+02
# Epoch 100 | Train total: 1.462e+01 | Train disp: 4.471e-03 | Train force: 1.461e+02 | Valid total: 1.177e+01 | Valid disp: 2.137e-03 | Valid force: 1.177e+02
# Epoch 200 | Train total: 9.231e+00 | Train disp: 4.489e-03 | Train force: 9.227e+01 | Valid total: 7.889e+00 | Valid disp: 2.177e-03 | Valid force: 7.886e+01
# Epoch 300 | Train total: 6.504e+00 | Train disp: 4.503e-03 | Train force: 6.500e+01 | Valid total: 5.909e+00 | Valid disp: 2.201e-03 | Valid force: 5.907e+01
# Epoch 400 | Train total: 5.402e+00 | Train disp: 4.508e-03 | Train force: 5.397e+01 | Valid total: 5.047e+00 | Valid disp: 2.209e-03 | Valid force: 5.044e+01
# [eval] arch=chol_stiffness_mlp seed=1 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=chol_stiffness_mlp seed=1 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=chol_stiffness_mlp seed=1 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=chol_stiffness_mlp seed=1 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=chol_stiffness_mlp seed=1 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=chol_stiffness_mlp seed=1 hreg=0.0001 largest_eval=1 (by monotonicity)
#
# [train] arch=chol_stiffness_mlp seed=2 hreg=0 train_max_dlambda=0.01
# ==========================================================================================
# Running architecture: chol_stiffness_mlp
#   model_cls               : CholeskyPlusStiffnessNN
#   which_case              : MLP
#   hidden                  : (10, 10)
#   input_mode              : invariant
#   only_stretching_NN      : True
#   only_bending_NN         : False
#   activation              : tanh
#   corr_factor             : 0.05
#   zero_reference          : True
#   seed                    : 2
#   n_epochs                : 500
#   lr                      : 0.005
#   weight_decay            : 0.0
#   max_dlambda             : 0.01
#   iters                   : 10
#   ls_steps                : 10
#   abs_tol                 : 0.0001
#   rel_tol                 : 0.0001
#   early_stop              : True
#   training fail_on_nonconvergence       : False
#   validation loss fail_on_nonconvergence: False
#   prediction fail_on_nonconvergence     : False
#   early_stopping          : True
#   early_stopping_patience : 200
#   early_stopping_warmup   : 200
#   restore_best_model      : True
#   hessian_reg_strength    : 0.0
#   hessian_reg_probes      : 1
#   hessian_reg_seed        : 0
#   force_key               : F
#   force_loss_strength     : 0.1
#   force_components        : (0,)
#   force_sign              : 1.0
#   save_force_predictions  : False
#   exp_dir                 : /Users/radha/GitRepos/dismech-jax/examples/slinky/slinky_2D/hessian_reg_max_dlambda_outputs_n3_slinky_sim/chol_stiffness_mlp__hid_10x10__inp_invariant__stretchNN_1__bendNN_0__act_tanh__corr_0.05__zr1__seed_2__mdl_0.01__it_10__floss_0.1__fcomp_0__fsign_1
# ==========================================================================================
# Epoch 000 | Train total: 2.681e+01 | Train disp: 4.709e-03 | Train force: 2.680e+02 | Valid total: 1.984e+01 | Valid disp: 2.293e-03 | Valid force: 1.983e+02
# Epoch 100 | Train total: 1.479e+01 | Train disp: 4.476e-03 | Train force: 1.478e+02 | Valid total: 1.186e+01 | Valid disp: 2.137e-03 | Valid force: 1.186e+02
# Epoch 200 | Train total: 9.334e+00 | Train disp: 4.490e-03 | Train force: 9.329e+01 | Valid total: 7.964e+00 | Valid disp: 2.178e-03 | Valid force: 7.962e+01
# Epoch 300 | Train total: 6.583e+00 | Train disp: 4.504e-03 | Train force: 6.579e+01 | Valid total: 5.974e+00 | Valid disp: 2.201e-03 | Valid force: 5.971e+01
# Epoch 400 | Train total: 5.468e+00 | Train disp: 4.509e-03 | Train force: 5.464e+01 | Valid total: 5.106e+00 | Valid disp: 2.210e-03 | Valid force: 5.104e+01
# [eval] arch=chol_stiffness_mlp seed=2 hreg=0 eval steps=(0.001, 0.01, 0.1, 1.0)
# [done] arch=chol_stiffness_mlp seed=2 hreg=0 train_success=True largest_eval=1.0
# [saturate] arch=chol_stiffness_mlp seed=2 reached largest eval max_dlambda=1 at hreg=0; remaining hregs for this seed will be marked inferred.
# [inferred] arch=chol_stiffness_mlp seed=2 hreg=1e-08 largest_eval=1 (by monotonicity)
# [inferred] arch=chol_stiffness_mlp seed=2 hreg=1e-06 largest_eval=1 (by monotonicity)
# [inferred] arch=chol_stiffness_mlp seed=2 hreg=0.0001 largest_eval=1 (by monotonicity)

# %% [markdown]
# ## Load Summary Tables

# %%
summary_path = OUTPUT_DIR / "summary.csv"
progress_path = OUTPUT_DIR / "progress.jsonl"

summary = pd.read_csv(summary_path)
with open(progress_path) as f:
    progress = [json.loads(line) for line in f if line.strip()]

eval_rows = []
for rec in progress:
    for item in rec.get("eval_by_max_dlambda", []):
        eval_rows.append({
            "arch_name": rec["arch_name"],
            "seed": rec["seed"],
            "hessian_reg_strength": rec["hessian_reg_strength"],
            "eval_max_dlambda": item["max_dlambda"],
            "success": bool(item["success"]),
            "valid_displacement_mse": item.get("valid_displacement_mse", np.nan),
        })
eval_df = pd.DataFrame(eval_rows)

display(summary.head())
display(eval_df.head())
# Out:
#               arch_name  seed  hessian_reg_strength  train_success  \
# 0  diag_energy_baseline     0          0.000000e+00           True
# 1  diag_energy_baseline     0          1.000000e-08           True
# 2  diag_energy_baseline     0          1.000000e-06           True
# 3  diag_energy_baseline     0          1.000000e-04           True
# 4  diag_energy_baseline     1          0.000000e+00           True
#
#    inferred_by_monotonicity  failure_reason  train_max_dlambda  \
# 0                     False             NaN               0.01
# 1                      True             NaN               0.01
# 2                      True             NaN               0.01
# 3                      True             NaN               0.01
# 4                     False             NaN               0.01
#
#    largest_stable_eval_max_dlambda  best_eval_valid_displacement_mse  \
# 0                              1.0                          0.004626
# 1                              1.0                               NaN
# 2                              1.0                               NaN
# 3                              1.0                               NaN
# 4                              1.0                          0.004626
#
#    final_train_loss  ...  kappa_hat   L_adj_hat  sigma_min_min  sigma_max_max  \
# 0          0.036875  ...   4.495652  109.840496       5.973048      32.780379
# 1               NaN  ...        NaN         NaN            NaN            NaN
# 2               NaN  ...        NaN         NaN            NaN            NaN
# 3               NaN  ...        NaN         NaN            NaN            NaN
# 4          0.036875  ...   4.495652  109.840496       5.973048      32.780379
#
#    lambda_min_min  lambda_max_max  negative_min_eig_fraction  n_states  \
# 0        5.973048       32.780379                        0.0      15.0
# 1             NaN             NaN                        NaN       NaN
# 2             NaN             NaN                        NaN       NaN
# 3             NaN             NaN                        NaN       NaN
# 4        5.973048       32.780379                        0.0      15.0
#
#    n_adjacent_pairs                                            exp_dir
# 0              14.0  /Users/radha/GitRepos/dismech-jax/examples/sli...
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4              14.0  /Users/radha/GitRepos/dismech-jax/examples/sli...
#
# [5 rows x 22 columns]
#               arch_name  seed  hessian_reg_strength  eval_max_dlambda  \
# 0  diag_energy_baseline     0          0.000000e+00             1.000
# 1  diag_energy_baseline     0          0.000000e+00             0.100
# 2  diag_energy_baseline     0          0.000000e+00             0.010
# 3  diag_energy_baseline     0          0.000000e+00             0.001
# 4  diag_energy_baseline     0          1.000000e-08             1.000
#
#    success  valid_displacement_mse
# 0     True                0.004626
# 1     True                     NaN
# 2     True                     NaN
# 3     True                     NaN
# 4     True                     NaN

# %% [markdown]
# ## Paper Figure Panels

# %%
plt.rcParams.update({"font.size": 10, "figure.dpi": 130})

plot_df = summary[summary["train_success"] == True].copy()
plot_df["hreg_plot"] = plot_df["hessian_reg_strength"].replace(0.0, 1e-10)

fig, axes = plt.subplots(1, 3, figsize=(13.5, 3.6), constrained_layout=True)

for arch, group in plot_df.groupby("arch_name"):
    agg = group.groupby("hreg_plot")["largest_stable_eval_max_dlambda"].agg(["mean", "std"]).reset_index()
    axes[0].errorbar(agg["hreg_plot"], agg["mean"], yerr=agg["std"], marker="o", capsize=3, label=arch)
axes[0].set_xscale("log")
axes[0].set_yscale("log")
axes[0].set_xlabel("Hessian regularizer strength")
axes[0].set_ylabel("Largest stable eval max dλ")
axes[0].set_title("Solver step robustness")
axes[0].grid(True, which="both", alpha=0.25)

for arch, group in plot_df.groupby("arch_name"):
    agg = group.groupby("hreg_plot")["best_eval_valid_displacement_mse"].agg(["mean", "std"]).reset_index()
    axes[1].errorbar(agg["hreg_plot"], agg["mean"], yerr=agg["std"], marker="o", capsize=3, label=arch)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[1].set_xlabel("Hessian regularizer strength")
axes[1].set_ylabel("Best eval displacement MSE")
axes[1].set_title("Accuracy tradeoff")
axes[1].grid(True, which="both", alpha=0.25)

for arch, group in plot_df.groupby("arch_name"):
    agg = group.groupby("hreg_plot")["kappa_hat"].agg(["median"]).reset_index()
    axes[2].plot(agg["hreg_plot"], agg["median"], marker="o", label=arch)
axes[2].set_xscale("log")
axes[2].set_yscale("log")
axes[2].set_xlabel("Hessian regularizer strength")
axes[2].set_ylabel("Median max Hessian condition proxy")
axes[2].set_title("Hessian conditioning")
axes[2].grid(True, which="both", alpha=0.25)

axes[2].legend(loc="best", fontsize=8)
fig.savefig(FIGURE_DIR / "n3_hessian_reg_ablation_panels.pdf", bbox_inches="tight")
fig.savefig(FIGURE_DIR / "n3_hessian_reg_ablation_panels.png", bbox_inches="tight")
plt.show()

# %%
success_rate = (
    eval_df.groupby(["arch_name", "hessian_reg_strength", "eval_max_dlambda"])["success"]
    .mean()
    .reset_index()
)

for arch in SELECTED_ARCHITECTURES:
    arch_df = success_rate[success_rate["arch_name"] == arch]
    if arch_df.empty:
        continue
    heat = arch_df.pivot(index="hessian_reg_strength", columns="eval_max_dlambda", values="success")
    fig, ax = plt.subplots(figsize=(7.0, 3.8), constrained_layout=True)
    im = ax.imshow(heat.values, aspect="auto", origin="lower", vmin=0, vmax=1, cmap="viridis")
    ax.set_xticks(np.arange(len(heat.columns)))
    ax.set_xticklabels([f"{v:g}" for v in heat.columns], rotation=45, ha="right")
    ax.set_yticks(np.arange(len(heat.index)))
    ax.set_yticklabels([f"{v:g}" for v in heat.index])
    ax.set_xlabel("Eval max dλ")
    ax.set_ylabel("Hessian regularizer strength")
    ax.set_title(f"Convergence success rate: {arch}")
    fig.colorbar(im, ax=ax, label="Fraction of seeds converged")
    fig.savefig(FIGURE_DIR / f"n3_success_heatmap_{arch}.pdf", bbox_inches="tight")
    fig.savefig(FIGURE_DIR / f"n3_success_heatmap_{arch}.png", bbox_inches="tight")
    plt.show()
